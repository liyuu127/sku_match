# %% [markdown]
# 对大模型调用错误的记录进行查询，尝试进行重试

# %%
import pandas as pd


def load_excel(file_path: str) -> pd.DataFrame:
    """
    读取Excel文件，验证必要列并处理空值
    要求文件必须包含"商品ID"和"商品名称"列（可修改required_cols适配实际列名）
    """
    try:
        df = pd.read_excel(file_path, engine='openpyxl')
        required_cols = ['商品ID', '商品名称']
        # 检查必要列是否存在
        missing_cols = [col for col in required_cols if col not in df.columns]
        if missing_cols:
            raise ValueError(f"缺少必要列：{', '.join(missing_cols)}，需包含{required_cols}")
        # 去除商品ID或名称为空的无效行
        df = df.dropna(subset=required_cols).reset_index(drop=True)
        # 强制转为字符串类型，避免数字ID/名称拼接出错（如科学计数法、格式丢失）
        df['商品ID'] = df['商品ID'].astype(str).str.strip()
        df['商品名称'] = df['商品名称'].astype(str).str.strip()
        return df
    except Exception as e:
        print(f"读取文件{file_path}失败：{str(e)}")
        raise

# %%
import math
import pandas as pd
import re


def pandas_str_to_series(s) -> pd.Series:
    # s为None或""或nan
    if s is None or s == "" or (isinstance(s, float) and math.isnan(s)):
        return None

    inner = s[s.find("(") + 1: s.rfind(")")]

    pattern = re.compile(r"(\w+)=('[^']*'|[^,]*)")
    data = {k: v.strip("'") if v.strip() != "nan" else None for k, v in pattern.findall(inner)}

    # 3️⃣ 转为 DataFrame
    df = pd.DataFrame([data])
    return df.iloc[0]

# %%
# 加载数据表文件
df = load_excel("../../output/补充Top3相似商品.xlsx")
df.head()
# Out:
#           商品ID                                           商品名称         规格  \
# 0  22639130381  【规格可选】30W充电套装 适用苹果8-14系列PD快充充电头 苹果手机数据线充电器 1个     单独 1米线
# 1  22638543544                          农夫山泉 饮用纯净水 550ml12瓶_包   550ml*12
# 2  22636514960                     红牛Red Bull 维生素风味饮料 250ml_罐   250ml*1罐
# 3  22640202093                            百岁山 饮用天然矿泉水 570ml_瓶        NaN
# 4  22740184269                          康师傅茉莉蜜茶调味茶饮品 1000ml_瓶  1000ml*1瓶
#
#                条码   折扣价     原价   活动  销售 店内一级分类 店内二级分类  ... 三级分类json  tag  \
# 0   6978410500134  6.75   6.75  NaN   3   所搜商品   所搜商品  ...      NaN  NaN
# 1   6921168560424  9.90  22.00  NaN  34     推荐     推荐  ...      NaN  NaN
# 2   6970640429988  8.07   8.23  NaN   7     推荐     推荐  ...      NaN  NaN
# 3  06922255466476  2.99   2.99  NaN   6     推荐     推荐  ...      NaN  NaN
# 4   6920459991985  5.54   5.65  NaN   1     推荐     推荐  ...      NaN  NaN
#
#    美团一级分类  美团二级分类        美团三级分类        skuid  \
# 0     NaN     NaN         直插充电器  41430057383
# 1     NaN     NaN         包装饮用水  41429308607
# 2     NaN     NaN  运动功能饮料（非健字号）  41430928019
# 3     NaN     NaN         天然矿泉水  41431324722
# 4     NaN     NaN           茶饮料  41669396232
#
#                                         相似商品1（ID-名称）  \
# 0  Pandas(商品ID='15408186991', 商品名称='iPhone16_15苹果...
# 1  Pandas(商品ID='18766628564', 商品名称='【农夫山泉】饮用天然水 5...
# 2  Pandas(商品ID='19220893481', 商品名称='红牛Red Bull 维生...
# 3  Pandas(商品ID='10908200588', 商品名称='百岁山 饮用天然水矿泉水 ...
# 4  Pandas(商品ID='10906519970', 商品名称='康师傅 茉莉清茶调味茶饮品...
#
#                                         相似商品2（ID-名称）  \
# 0  Pandas(商品ID='15394518849', 商品名称='苹果iPhone13_14...
# 1  Pandas(商品ID='18766628564', 商品名称='【农夫山泉】饮用天然水 5...
# 2                                                NaN
# 3                                                NaN
# 4  Pandas(商品ID='21147266243', 商品名称='康师傅 青梅绿茶果味茶饮品...
#
#                                         相似商品3（ID-名称）  \
# 0                                                NaN
# 1  Pandas(商品ID='20440643609', 商品名称='【农夫山泉】 饮用天然水 ...
# 2                                                NaN
# 3                                                NaN
# 4  Pandas(商品ID='10908201285', 商品名称='康师傅 茉莉蜜茶花茶调味花...
#
#                                                 相似商品
# 0                                                NaN
# 1  Pandas(商品ID='18766628564', 商品名称='【农夫山泉】饮用天然水 5...
# 2  Pandas(商品ID='19220893481', 商品名称='红牛Red Bull 维生...
# 3  Pandas(商品ID='10908200588', 商品名称='百岁山 饮用天然水矿泉水 ...
# 4  Pandas(商品ID='10908201285', 商品名称='康师傅 茉莉蜜茶花茶调味花...
#
# [5 rows x 29 columns]

# %%
# 提取相似商品列值为error的记录，相似商品列可能为None
error_rows = df[df['相似商品'].notnull() & df['相似商品'].str.contains('error')]
error_rows
# Out:
# Empty DataFrame
# Columns: [商品ID, 商品名称, 规格, 条码, 折扣价, 原价, 活动, 销售, 店内一级分类, 店内二级分类, 图片, 库存, 描述, 属性, 好评率, 想买人数, 点赞数, 最小订购数, 标识, 三级分类json, tag, 美团一级分类, 美团二级分类, 美团三级分类, skuid, 相似商品1（ID-名称）, 相似商品2（ID-名称）, 相似商品3（ID-名称）, 相似商品]
# Index: []
#
# [0 rows x 29 columns]

# %%
# error_rows数据信息，多少行，多少列
error_rows.shape
# Out:
# (8, 29)

# %%
from Limter import RateLimiter

# 设置限流器
limiter = RateLimiter()

# %%
from llm_match import process_llm_row, llm_rank

# 迭代错误记录error_rows, 尝试进行重试
for index, row in error_rows.iterrows():
    print(f"正在处理错误记录：{index} - {row['商品名称']}")
    await limiter.record_call(800)
    # 重新解析相似商品1（ID-名称）列为Series对象，值为str,举例：Pandas(商品ID='10908200588', 商品名称='百岁山 饮用天然水矿泉水 570ml_瓶', 规格='570ml*1瓶', 条码=6922255451427.0, 折扣价=3.0, 原价=3.5, 活动=nan, 销售=72, 店内一级分类='水丨饮料', 店内二级分类='全部', 图片='http://p0.meituan.net/shangouproductapi/c...
    similar_product1 = pandas_str_to_series(row['相似商品1（ID-名称）'])
    similar_product2 = pandas_str_to_series(row['相似商品2（ID-名称）'])
    similar_product3 = pandas_str_to_series(row['相似商品3（ID-名称）'])
    # print(similar_product1['商品名称'])

    # 重新进行模型匹配判断
    # similar_product1为None，则为""
    top1 = similar_product1['商品名称'] if similar_product1 is not None else ""
    top2 = similar_product2['商品名称'] if similar_product2 is not None else ""
    top3 = similar_product3['商品名称'] if similar_product3 is not None else ""
    idx = await llm_rank(row.商品名称, top1, top2, top3)
    print(f"匹配结果：{idx}")
    # 更新error_rows相似商品字段
    if idx == 1:
        error_rows.at[index, '相似商品'] = error_rows.loc[index, '相似商品1（ID-名称）']
    elif idx == 2:
        error_rows.at[index, '相似商品'] = error_rows.loc[index, '相似商品2（ID-名称）']
    elif idx == 3:
        error_rows.at[index, '相似商品'] = error_rows.loc[index, '相似商品3（ID-名称）']
    elif idx == 0:
        error_rows.at[index, '相似商品'] = None
    else:
        error_rows.at[index, '相似商品'] = 'error'
        print("匹配结果错误")
# Out:
# 正在处理错误记录：10 - 康师傅 冰力十足冰红茶柠檬口味茶饮品 500ml_瓶
# 正在处理： 康师傅 冰力十足冰红茶柠檬口味茶饮品 500ml_瓶
# 匹配结果：0
# 正在处理错误记录：15 - 香飘飘蜜谷 桃桃红柚果汁茶饮料 400ml_杯
# 正在处理： 香飘飘蜜谷 桃桃红柚果汁茶饮料 400ml_杯
# 匹配结果：0
# 正在处理错误记录：17 - 三得利 0能量0糖清香微甜茉莉乌龙茶饮料 500ml_瓶
# 正在处理： 三得利 0能量0糖清香微甜茉莉乌龙茶饮料 500ml_瓶
# 匹配结果：1
# 正在处理错误记录：23 - 王老吉 凉茶植物饮料 500ml_瓶
# 正在处理： 王老吉 凉茶植物饮料 500ml_瓶
# 匹配结果：1
# 正在处理错误记录：31 - 可口可乐 畅爽装汽水 680ml_瓶
# 正在处理： 可口可乐 畅爽装汽水 680ml_瓶
# 匹配结果：0
# 正在处理错误记录：35 - 乌苏 11°P乌苏啤酒罐装 500ml_听
# 正在处理： 乌苏 11°P乌苏啤酒罐装 500ml_听
# 匹配结果：0
# 正在处理错误记录：38 - 得宝 抽取式面巾纸 90抽_袋
# 正在处理： 得宝 抽取式面巾纸 90抽_袋
# 匹配结果：0
# 正在处理错误记录：40 - 百事可乐 可乐型汽水 330ml_罐
# 正在处理： 百事可乐 可乐型汽水 330ml_罐
# 匹配结果：1
# 正在处理错误记录：58 - 陶华碧老干妈 固形物不低于50%风味鸡油辣椒 280g_瓶
# 正在处理： 陶华碧老干妈 固形物不低于50%风味鸡油辣椒 280g_瓶
# 匹配结果：0
# 正在处理错误记录：60 - 李锦记薄盐生抽酿造酱油 500ml_瓶
# 正在处理： 李锦记薄盐生抽酿造酱油 500ml_瓶
# 商品：李锦记薄盐生抽酿造酱油 500ml_瓶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  \t\t\t\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：62 - 悠宜UNNY CLUB  水感清颜卸妆湿巾 7g_片8
# 正在处理： 悠宜UNNY CLUB  水感清颜卸妆湿巾 7g_片8
# 匹配结果：1
# 正在处理错误记录：69 - 【菊花茶】 元气森林 菊花茶 600ml_瓶3
# 正在处理： 【菊花茶】 元气森林 菊花茶 600ml_瓶3
# 商品：【菊花茶】 元气森林 菊花茶 600ml_瓶3 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_inde...    \n  \n  \n    \n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：71 - 立白 大师香氛梦幻格拉斯玫瑰天然洗衣液 2000g_瓶
# 正在处理： 立白 大师香氛梦幻格拉斯玫瑰天然洗衣液 2000g_瓶
# 匹配结果：1
# 正在处理错误记录：76 - 【柿子】好柿连连 钥匙扣毛绒可爱挂件挂饰_个
# 正在处理： 【柿子】好柿连连 钥匙扣毛绒可爱挂件挂饰_个
# 匹配结果：0
# 正在处理错误记录：79 - 迪味臻辣棒火锅味 102g_袋
# 正在处理： 迪味臻辣棒火锅味 102g_袋
# 商品：迪味臻辣棒火锅味 102g_袋 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：84 - 清清美 素肌沐浴花 颜色随机 1个
# 正在处理： 清清美 素肌沐浴花 颜色随机 1个
# 匹配结果：0
# 正在处理错误记录：102 - 麻辣王子 很麻很辣地道辣条 18g_袋
# 正在处理： 麻辣王子 很麻很辣地道辣条 18g_袋
# 匹配结果：1
# 正在处理错误记录：120 - 张奇龙唐僧素牛排调味面制品 散装称重 约22g_袋
# 正在处理： 张奇龙唐僧素牛排调味面制品 散装称重 约22g_袋
# 匹配结果：0
# 正在处理错误记录：121 - 邦爵 防风打火机 约20g_个
# 正在处理： 邦爵 防风打火机 约20g_个
# 匹配结果：0
# 正在处理错误记录：125 - 迪味臻 香辣味素毛肚28g_袋
# 正在处理： 迪味臻 香辣味素毛肚28g_袋
# 商品：迪味臻 香辣味素毛肚28g_袋 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 1\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：126 - 【山姆】Member'sMark 弱碱性天然矿泉水 300mL_瓶
# 正在处理： 【山姆】Member'sMark 弱碱性天然矿泉水 300mL_瓶
# 匹配结果：1
# 正在处理错误记录：132 - 农夫山泉 饮用纯净水 550ml_瓶
# 正在处理： 农夫山泉 饮用纯净水 550ml_瓶
# 匹配结果：1
# 正在处理错误记录：191 - 小熊刺绣中筒袜 新款日系学院风袜子 1双 泰迪熊竖条秋冬韩版女袜 颜色随机
# 正在处理： 小熊刺绣中筒袜 新款日系学院风袜子 1双 泰迪熊竖条秋冬韩版女袜 颜色随机
# 匹配结果：3
# 正在处理错误记录：200 - 笠王 成人非一次性雨衣1件 旅游户外徒步袖口皮筋加厚EVA半透明雨披
# 正在处理： 笠王 成人非一次性雨衣1件 旅游户外徒步袖口皮筋加厚EVA半透明雨披
# 匹配结果：1
# 正在处理错误记录：210 - 增压花洒五档喷头1个 加压沐浴热水器软管浴霸莲蓬头超强淋浴
# 正在处理： 增压花洒五档喷头1个 加压沐浴热水器软管浴霸莲蓬头超强淋浴
# 匹配结果：2
# 正在处理错误记录：215 - 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
# 正在处理： 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
# 匹配结果：0
# 正在处理错误记录：218 - 【尺码可选】防水黑色男士棉拖鞋 1双 秋冬季男女居家外出防滑加绒情侣棉鞋保暖拖鞋
# 正在处理： 【尺码可选】防水黑色男士棉拖鞋 1双 秋冬季男女居家外出防滑加绒情侣棉鞋保暖拖鞋
# 商品：【尺码可选】防水黑色男士棉拖鞋 1双 秋冬季男女居家外出防滑加绒情侣棉鞋保暖拖鞋 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 2\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：222 - 国标热水袋充电式暖宝宝暖水袋1个 防爆自动断电热水袋暖手加厚加绒
# 正在处理： 国标热水袋充电式暖宝宝暖水袋1个 防爆自动断电热水袋暖手加厚加绒
# 匹配结果：0
# 正在处理错误记录：230 - 【加强型】十月暖暖卡通暖贴1片 持久发热暖肚暖身贴
# 正在处理： 【加强型】十月暖暖卡通暖贴1片 持久发热暖肚暖身贴
# 商品：【加强型】十月暖暖卡通暖贴1片 持久发热暖肚暖身贴 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：234 - 日式静音棉拖鞋男女同款1双 静音拖鞋冬季软底无声女士四季室内家居防滑木地板棉拖鞋子
# 正在处理： 日式静音棉拖鞋男女同款1双 静音拖鞋冬季软底无声女士四季室内家居防滑木地板棉拖鞋子
# 匹配结果：3
# 正在处理错误记录：235 - 冬季电动车保暖手套1双 摩托车加绒加厚护手套防水挡风透明雨罩通用款
# 正在处理： 冬季电动车保暖手套1双 摩托车加绒加厚护手套防水挡风透明雨罩通用款
# 匹配结果：3
# 正在处理错误记录：238 - 围脖帽子 冬户外骑车防寒防风护颈飞虎帽 黑色_个 加厚保暖护耳面罩 抓绒头套
# 正在处理： 围脖帽子 冬户外骑车防寒防风护颈飞虎帽 黑色_个 加厚保暖护耳面罩 抓绒头套
# 商品：围脖帽子 冬户外骑车防寒防风护颈飞虎帽 黑色_个 加厚保暖护耳面罩 抓绒头套 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 1\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：247 - 冬季骑行手套保暖手套女1双 加绒手套学生分指毛线手套可爱笑脸触屏针织手套 颜色随机
# 正在处理： 冬季骑行手套保暖手套女1双 加绒手套学生分指毛线手套可爱笑脸触屏针织手套 颜色随机
# 商品：冬季骑行手套保暖手套女1双 加绒手套学生分指毛线手套可爱笑脸触屏针织手套 颜色随机 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_inde...  \t\t\t\t\t\t\t\t\t\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：253 - 尼龙运动护膝黑色1对 L_XL针织四面弹力护膝透气吸汗健身登山护膝保暖防滑护膝
# 正在处理： 尼龙运动护膝黑色1对 L_XL针织四面弹力护膝透气吸汗健身登山护膝保暖防滑护膝
# 商品：尼龙运动护膝黑色1对 L_XL针织四面弹力护膝透气吸汗健身登山护膝保暖防滑护膝 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：254 - 志高 烘鞋器 1个 家用智能恒温除湿暖鞋器便携除臭杀菌干鞋机 白色
# 正在处理： 志高 烘鞋器 1个 家用智能恒温除湿暖鞋器便携除臭杀菌干鞋机 白色
# 匹配结果：0
# 正在处理错误记录：255 - 【规格可选】春秋季一体高腰光腿神器 1条 女加绒加厚保暖连裤袜加绒黑色透肤丝袜打底裤黑丝
# 正在处理： 【规格可选】春秋季一体高腰光腿神器 1条 女加绒加厚保暖连裤袜加绒黑色透肤丝袜打底裤黑丝
# 匹配结果：1
# 正在处理错误记录：266 - 【毛绒长款睡袍】卡皮巴拉冬季新款加厚睡袍卡通可爱风珊瑚绒睡衣女家居服_件
# 正在处理： 【毛绒长款睡袍】卡皮巴拉冬季新款加厚睡袍卡通可爱风珊瑚绒睡衣女家居服_件
# 商品：【毛绒长款睡袍】卡皮巴拉冬季新款加厚睡袍卡通可爱风珊瑚绒睡衣女家居服_件 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 3\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：268 - 格子围巾男款1条 秋冬季加厚保暖学生韩系加厚百搭情侣围脖
# 正在处理： 格子围巾男款1条 秋冬季加厚保暖学生韩系加厚百搭情侣围脖
# 商品：格子围巾男款1条 秋冬季加厚保暖学生韩系加厚百搭情侣围脖 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 2\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：273 - 光腿神器 1条 加绒双层肤色连裤袜 加厚高腰保暖打底裤
# 正在处理： 光腿神器 1条 加绒双层肤色连裤袜 加厚高腰保暖打底裤
# 匹配结果：1
# 正在处理错误记录：276 - 男士面包服1件 冬季加厚棉衣宽松新款棉服休闲棉袄立领外套百搭保暖
# 正在处理： 男士面包服1件 冬季加厚棉衣宽松新款棉服休闲棉袄立领外套百搭保暖
# 商品：男士面包服1件 冬季加厚棉衣宽松新款棉服休闲棉袄立领外套百搭保暖 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：280 - 韩系简约男女加厚棉服规格可选 立领情侣潮牌棉袄防寒保暖百塔外套面包服棉衣~
# 正在处理： 韩系简约男女加厚棉服规格可选 立领情侣潮牌棉袄防寒保暖百塔外套面包服棉衣~
# 匹配结果：3
# 正在处理错误记录：281 - 农夫山泉 饮用纯净水 550ml12瓶_包
# 正在处理： 农夫山泉 饮用纯净水 550ml12瓶_包
# 匹配结果：0
# 正在处理错误记录：282 - 百岁山 饮用天然矿泉水 570ml_瓶
# 正在处理： 百岁山 饮用天然矿泉水 570ml_瓶
# 匹配结果：1
# 正在处理错误记录：287 - 农夫山泉 饮用纯净水 550ml_瓶
# 正在处理： 农夫山泉 饮用纯净水 550ml_瓶
# 匹配结果：1
# 正在处理错误记录：307 - 可口可乐雪碧 清爽柠檬味汽水 330ml_罐
# 正在处理： 可口可乐雪碧 清爽柠檬味汽水 330ml_罐
# 匹配结果：1
# 正在处理错误记录：308 - 好哇塞小青柠汽水520ml_瓶
# 正在处理： 好哇塞小青柠汽水520ml_瓶
# 匹配结果：0
# 正在处理错误记录：318 - 东鹏特饮 东鹏特饮维生素功能饮料 500ml_瓶
# 正在处理： 东鹏特饮 东鹏特饮维生素功能饮料 500ml_瓶
# 匹配结果：2
# 正在处理错误记录：329 - 7喜7UP 冰爽柠檬味汽水 2l_瓶
# 正在处理： 7喜7UP 冰爽柠檬味汽水 2l_瓶
# 匹配结果：2
# 正在处理错误记录：339 - 乐虎HI-TIGER 牛磺酸肌醇饮料 500ml_瓶
# 正在处理： 乐虎HI-TIGER 牛磺酸肌醇饮料 500ml_瓶
# 商品：乐虎HI-TIGER 牛磺酸肌醇饮料 500ml_瓶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：341 - 【7喜】 柠檬味汽水碳酸饮料 330ml6听_组
# 正在处理： 【7喜】 柠檬味汽水碳酸饮料 330ml6听_组
# 匹配结果：0
# 正在处理错误记录：349 - 北冰洋橙汁汽水 330毫升6听 塑包装
# 正在处理： 北冰洋橙汁汽水 330毫升6听 塑包装
# 商品：北冰洋橙汁汽水 330毫升6听 塑包装 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：361 - 康师傅 冰红茶柠檬口味茶饮品 500ml15瓶_箱
# 正在处理： 康师傅 冰红茶柠檬口味茶饮品 500ml15瓶_箱
# 匹配结果：3
# 正在处理错误记录：363 - 元气森林 冰茶减糖葡萄柚绿茶茶饮料 900ml_瓶
# 正在处理： 元气森林 冰茶减糖葡萄柚绿茶茶饮料 900ml_瓶
# 商品：元气森林 冰茶减糖葡萄柚绿茶茶饮料 900ml_瓶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 1\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：370 - 味全每日C 100胡萝卜果蔬混合汁 300ml_瓶
# 正在处理： 味全每日C 100胡萝卜果蔬混合汁 300ml_瓶
# 匹配结果：0
# 正在处理错误记录：386 - 可口可乐雪碧 高罐清爽柠檬味汽水 330ml_罐
# 正在处理： 可口可乐雪碧 高罐清爽柠檬味汽水 330ml_罐
# 匹配结果：1
# 正在处理错误记录：387 - 可口可乐芬达 橙味汽水 500ml_瓶
# 正在处理： 可口可乐芬达 橙味汽水 500ml_瓶
# 匹配结果：2
# 正在处理错误记录：392 - 可口可乐芬达 无糖橙味汽水 500ml_瓶
# 正在处理： 可口可乐芬达 无糖橙味汽水 500ml_瓶
# 匹配结果：2
# 正在处理错误记录：404 - 维他奶维他 真柠檬柠檬味茶饮料 250ml6盒_包
# 正在处理： 维他奶维他 真柠檬柠檬味茶饮料 250ml6盒_包
# 匹配结果：1
# 正在处理错误记录：406 - 农夫山泉东方树叶 0卡路里茉莉花茶原味茶饮料 900ml_瓶
# 正在处理： 农夫山泉东方树叶 0卡路里茉莉花茶原味茶饮料 900ml_瓶
# 匹配结果：1
# 正在处理错误记录：407 - 雪菲力 荔枝味复合果汁饮料 250ml_盒
# 正在处理： 雪菲力 荔枝味复合果汁饮料 250ml_盒
# 匹配结果：1
# 正在处理错误记录：411 - 农夫山泉水溶C100 西柚汁饮料 445ml_瓶
# 正在处理： 农夫山泉水溶C100 西柚汁饮料 445ml_瓶
# 商品：农夫山泉水溶C100 西柚汁饮料 445ml_瓶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_inde...  \t  \t  \t  \t  \t\t}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：420 - 红牛 维生素牛磺酸饮料 250ml_罐
# 正在处理： 红牛 维生素牛磺酸饮料 250ml_罐
# 匹配结果：1
# 正在处理错误记录：426 - 雪花 8°P清爽啤酒 330ml6听_包
# 正在处理： 雪花 8°P清爽啤酒 330ml6听_包
# 匹配结果：1
# 正在处理错误记录：433 - 喜力Heineken 11.4°P啤酒 500ml3罐_包
# 正在处理： 喜力Heineken 11.4°P啤酒 500ml3罐_包
# 匹配结果：1
# 正在处理错误记录：434 - 牛栏山 42度白牛二牛栏山陈酿白酒 500ml_瓶
# 正在处理： 牛栏山 42度白牛二牛栏山陈酿白酒 500ml_瓶
# 匹配结果：2
# 正在处理错误记录：453 - 雪花Snowbeer 12.0°P老雪雪花啤酒 640ml_瓶
# 正在处理： 雪花Snowbeer 12.0°P老雪雪花啤酒 640ml_瓶
# 匹配结果：1
# 正在处理错误记录：454 - 锐澳微醺 3度葡萄白兰地风味鸡尾酒 330ml_罐
# 正在处理： 锐澳微醺 3度葡萄白兰地风味鸡尾酒 330ml_罐
# 匹配结果：0
# 正在处理错误记录：460 - 锐澳强爽 8度RIO强爽白桃伏特加风味鸡尾酒 500ml_罐
# 正在处理： 锐澳强爽 8度RIO强爽白桃伏特加风味鸡尾酒 500ml_罐
# 匹配结果：3
# 正在处理错误记录：461 - 乌苏啤酒 11°P红乌苏啤酒 620ml_瓶
# 正在处理： 乌苏啤酒 11°P红乌苏啤酒 620ml_瓶
# 匹配结果：0
# 正在处理错误记录：469 - 雪花 8°P清爽啤酒 500ml_听
# 正在处理： 雪花 8°P清爽啤酒 500ml_听
# 匹配结果：1
# 正在处理错误记录：471 - 青岛啤酒光明啤酒 7.5°P超纯啤酒 500ml4听_包
# 正在处理： 青岛啤酒光明啤酒 7.5°P超纯啤酒 500ml4听_包
# 商品：青岛啤酒光明啤酒 7.5°P超纯啤酒 500ml4听_包 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：473 - 会稽山 14度会稽山纯正绍兴酒 500ml_瓶
# 正在处理： 会稽山 14度会稽山纯正绍兴酒 500ml_瓶
# 匹配结果：0
# 正在处理错误记录：485 - 旺仔 原味复原乳牛奶调制乳 500ml(125ml4盒)_件
# 正在处理： 旺仔 原味复原乳牛奶调制乳 500ml(125ml4盒)_件
# 匹配结果：3
# 正在处理错误记录：489 - 味全 原味乳酸菌饮品(杀菌型) 380ml_瓶
# 正在处理： 味全 原味乳酸菌饮品(杀菌型) 380ml_瓶
# 匹配结果：0
# 正在处理错误记录：491 - 李子园 甜牛奶饮品 450ml_瓶
# 正在处理： 李子园 甜牛奶饮品 450ml_瓶
# 匹配结果：0
# 正在处理错误记录：500 - 维他奶 0胆固醇低脂无负担原味豆奶 250ml6盒_提
# 正在处理： 维他奶 0胆固醇低脂无负担原味豆奶 250ml6盒_提
# 匹配结果：2
# 正在处理错误记录：503 - 伊利畅轻 燕麦+黄桃风味发酵乳 250g_瓶
# 正在处理： 伊利畅轻 燕麦+黄桃风味发酵乳 250g_瓶
# 商品：伊利畅轻 燕麦+黄桃风味发酵乳 250g_瓶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  \t\t\n\t\t\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：512 - 维他奶 巧克力味豆奶饮料 250ml6盒_件
# 正在处理： 维他奶 巧克力味豆奶饮料 250ml6盒_件
# 匹配结果：1
# 正在处理错误记录：514 - 椰树牌 椰汁植物蛋白饮料 1l_盒
# 正在处理： 椰树牌 椰汁植物蛋白饮料 1l_盒
# 匹配结果：1
# 正在处理错误记录：521 - 好丽友 红丝绒莓莓味Q蒂蛋糕 168g(28g6枚)_盒
# 正在处理： 好丽友 红丝绒莓莓味Q蒂蛋糕 168g(28g6枚)_盒
# 匹配结果：0
# 正在处理错误记录：535 - 达利园 香橙味法式软面包 10枚200g_袋
# 正在处理： 达利园 香橙味法式软面包 10枚200g_袋
# 匹配结果：0
# 正在处理错误记录：536 - 好丽友派 清新抹茶本味涂饰蛋类芯饼 216g(6枚)_盒
# 正在处理： 好丽友派 清新抹茶本味涂饰蛋类芯饼 216g(6枚)_盒
# 匹配结果：0
# 正在处理错误记录：538 - 达利园 香蕉味卷式夹心糕点瑞士卷 200g(10枚)_袋
# 正在处理： 达利园 香蕉味卷式夹心糕点瑞士卷 200g(10枚)_袋
# 匹配结果：0
# 正在处理错误记录：545 - 好丽友 巧克力味涂饰蛋类芯饼 445g(12枚)_盒
# 正在处理： 好丽友 巧克力味涂饰蛋类芯饼 445g(12枚)_盒
# 匹配结果：0
# 正在处理错误记录：548 - 盼盼 奶香味法式软面包 200g(10枚)_袋
# 正在处理： 盼盼 奶香味法式软面包 200g(10枚)_袋
# 匹配结果：0
# 正在处理错误记录：554 - 达利园 香橙味法式软面包 360g(18枚)_袋
# 正在处理： 达利园 香橙味法式软面包 360g(18枚)_袋
# 匹配结果：0
# 正在处理错误记录：556 - 百草味 手撕面包 280g_袋
# 正在处理： 百草味 手撕面包 280g_袋
# 商品：百草味 手撕面包 280g_袋 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：558 - 福乐回头 3+2紫米面包 80g_袋
# 正在处理： 福乐回头 3+2紫米面包 80g_袋
# 匹配结果：1
# 正在处理错误记录：559 - 粮小子福乐回头 蓝莓牛奶味面包 80g_袋
# 正在处理： 粮小子福乐回头 蓝莓牛奶味面包 80g_袋
# 匹配结果：0
# 正在处理错误记录：564 - U吧U吧 轻咸肉松面包 90g_袋
# 正在处理： U吧U吧 轻咸肉松面包 90g_袋
# 匹配结果：0
# 正在处理错误记录：567 - 秀峰香 肉松海苔面包 80g_袋
# 正在处理： 秀峰香 肉松海苔面包 80g_袋
# 匹配结果：0
# 正在处理错误记录：572 - 双汇双汇王中王 优级火腿肠 240g(30g8支)_袋
# 正在处理： 双汇双汇王中王 优级火腿肠 240g(30g8支)_袋
# 匹配结果：0
# 正在处理错误记录：577 - 康师傅 香辣牛肉拌面 144g_桶 新旧包装随机发
# 正在处理： 康师傅 香辣牛肉拌面 144g_桶 新旧包装随机发
# 匹配结果：0
# 正在处理错误记录：584 - 康师傅 老坛酸菜牛肉拌面 160g_碗
# 正在处理： 康师傅 老坛酸菜牛肉拌面 160g_碗
# 匹配结果：0
# 正在处理错误记录：589 - 康师傅 卤香牛肉面 110g_桶
# 正在处理： 康师傅 卤香牛肉面 110g_桶
# 商品：康师傅 卤香牛肉面 110g_桶 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：603 - 银鹭 绿豆汤罐头 370g_罐
# 正在处理： 银鹭 绿豆汤罐头 370g_罐
# 匹配结果：0
# 正在处理错误记录：604 - 百草味 固形物不低于60%水果捞黄桃罐头 312g_罐
# 正在处理： 百草味 固形物不低于60%水果捞黄桃罐头 312g_罐
# 匹配结果：0
# 正在处理错误记录：610 - 康师傅 香菇炖鸡面 101g_袋
# 正在处理： 康师傅 香菇炖鸡面 101g_袋
# 匹配结果：1
# 正在处理错误记录：613 - 康师傅 卤香牛肉拌面 146g_碗
# 正在处理： 康师傅 卤香牛肉拌面 146g_碗
# 匹配结果：0
# 正在处理错误记录：619 - 康师傅 酸香爽金汤肥牛面 105g_袋
# 正在处理： 康师傅 酸香爽金汤肥牛面 105g_袋
# 匹配结果：0
# 正在处理错误记录：620 - 汤达人 日式豚骨拉面 125g5包_袋
# 正在处理： 汤达人 日式豚骨拉面 125g5包_袋
# 商品：汤达人 日式豚骨拉面 125g5包_袋 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：624 - 海底捞 酸辣激爽酸辣粉 144g(粉丝饼60g＋配料84g)_桶
# 正在处理： 海底捞 酸辣激爽酸辣粉 144g(粉丝饼60g＋配料84g)_桶
# 匹配结果：0
# 正在处理错误记录：632 - 海底捞 麻酱爆肚粉 142g_桶
# 正在处理： 海底捞 麻酱爆肚粉 142g_桶
# 匹配结果：0
# 正在处理错误记录：636 - 思念 冷冻低钠盐鸡蛋韭菜素水饺 455g_袋
# 正在处理： 思念 冷冻低钠盐鸡蛋韭菜素水饺 455g_袋
# 匹配结果：0
# 正在处理错误记录：638 - 汤达人 日式豚骨拉面 0.996kg(83g12杯)_箱
# 正在处理： 汤达人 日式豚骨拉面 0.996kg(83g12杯)_箱
# 匹配结果：1
# 正在处理错误记录：642 - 合味道 海鲜风味方便面 76g_杯3（新老包装随机发货）
# 正在处理： 合味道 海鲜风味方便面 76g_杯3（新老包装随机发货）
# 匹配结果：0
# 正在处理错误记录：645 - 汤达人 五合一日式豚骨拉面 625g6袋_箱
# 正在处理： 汤达人 五合一日式豚骨拉面 625g6袋_箱
# 匹配结果：0
# 正在处理错误记录：652 - 桂冠 原味香糯小圆子 250g_袋
# 正在处理： 桂冠 原味香糯小圆子 250g_袋
# 匹配结果：0
# 正在处理错误记录：672 - 好丽友呀!土豆 蜂蜜黄油味薯条 40g_袋
# 正在处理： 好丽友呀!土豆 蜂蜜黄油味薯条 40g_袋
# 匹配结果：0
# 正在处理错误记录：673 - 好丽友好友趣 韩国泡菜味原切马铃薯片 70g_袋
# 正在处理： 好丽友好友趣 韩国泡菜味原切马铃薯片 70g_袋
# 匹配结果：0
# 正在处理错误记录：674 - 上好佳 经典原味田园薯片 80g_袋
# 正在处理： 上好佳 经典原味田园薯片 80g_袋
# 匹配结果：0
# 正在处理错误记录：678 - 达利可比克copico 烧烤味薯片油炸型复合膨化食品 55g_袋
# 正在处理： 达利可比克copico 烧烤味薯片油炸型复合膨化食品 55g_袋
# 匹配结果：0
# 正在处理错误记录：686 - 好丽友好友趣 加勒比烤翅味原切马铃薯片 70g_袋
# 正在处理： 好丽友好友趣 加勒比烤翅味原切马铃薯片 70g_袋
# 匹配结果：0
# 正在处理错误记录：701 - 好丽友好友趣 多汁牛排味原切马铃薯片 70g_袋
# 正在处理： 好丽友好友趣 多汁牛排味原切马铃薯片 70g_袋
# 匹配结果：0
# 正在处理错误记录：702 - 百事食品乐事Lay's 无限青柠味薯片油炸型膨化食品 104g_罐
# 正在处理： 百事食品乐事Lay's 无限青柠味薯片油炸型膨化食品 104g_罐
# 匹配结果：1
# 正在处理错误记录：704 - 情人结 麻辣锅巴 76g_袋
# 正在处理： 情人结 麻辣锅巴 76g_袋
# 匹配结果：0
# 正在处理错误记录：708 - 好丽友薯愿 非油炸红酒牛排味焙烤马铃薯膨化食品 104g(内含2包)_桶
# 正在处理： 好丽友薯愿 非油炸红酒牛排味焙烤马铃薯膨化食品 104g(内含2包)_桶
# 商品：好丽友薯愿 非油炸红酒牛排味焙烤马铃薯膨化食品 104g(内含2包)_桶 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：711 - 乐事 无限滋香烤肉味薯片 104g_罐
# 正在处理： 乐事 无限滋香烤肉味薯片 104g_罐
# 匹配结果：0
# 正在处理错误记录：714 - 咪咪虾味油炸休闲小点心18g_袋
# 正在处理： 咪咪虾味油炸休闲小点心18g_袋
# 匹配结果：0
# 正在处理错误记录：722 - 雀巢脆脆鲨 巧克力味涂层威化饼干 18.6g_袋
# 正在处理： 雀巢脆脆鲨 巧克力味涂层威化饼干 18.6g_袋
# 商品：雀巢脆脆鲨 巧克力味涂层威化饼干 18.6g_袋 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：737 - 百事食品奇多 美式火鸡味干杯脆膨化食品 25g_袋
# 正在处理： 百事食品奇多 美式火鸡味干杯脆膨化食品 25g_袋
# 匹配结果：0
# 正在处理错误记录：738 - 上好佳 非油炸无反式脂肪草莓口味栗米条 70g_袋
# 正在处理： 上好佳 非油炸无反式脂肪草莓口味栗米条 70g_袋
# 匹配结果：0
# 正在处理错误记录：739 - Oishi上好佳 非油炸无反式脂肪草莓口味粟米条膨化食品 40g_袋
# 正在处理： Oishi上好佳 非油炸无反式脂肪草莓口味粟米条膨化食品 40g_袋
# 商品：Oishi上好佳 非油炸无反式脂肪草莓口味粟米条膨化食品 40g_袋 发生异常:
# 匹配结果：-1
# 匹配结果错误
# 正在处理错误记录：741 - 米多奇烤馍片50g孜然风味零食办公室休闲食品早餐小吃饼干
# 正在处理： 米多奇烤馍片50g孜然风味零食办公室休闲食品早餐小吃饼干
# 匹配结果：3
# 正在处理错误记录：748 - 小王子 麦烧香辣味 100g_包
# 正在处理： 小王子 麦烧香辣味 100g_包
# 匹配结果：0
# 正在处理错误记录：750 - 上好佳Oishi 无反式脂肪南美烧烤风味玉米卷膨化食品 80g_袋
# 正在处理： 上好佳Oishi 无反式脂肪南美烧烤风味玉米卷膨化食品 80g_袋
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[71], line 18
#      16 top2 = similar_product2['商品名称'] if similar_product2 is not None else ""
#      17 top3 = similar_product3['商品名称'] if similar_product3 is not None else ""
# ---> 18 idx = await llm_rank(row.商品名称, top1, top2, top3)
#      19 print(f"匹配结果：{idx}")
#      20 # 更新error_rows相似商品字段
#
# File ~/workplace/project/hub/sku_match/src/llm_match.py:75, in llm_rank(product_name, top1, top2, top3)
#      71 prompt_format = rank_prompt.format(origin_product=product_name, top1_candidate=top1,
#      72                                    top2_candidate=top2, top3_candidate=top3)
#      74 try:
# ---> 75     rankSelect = await asyncio.wait_for(model.ainvoke([HumanMessage(content=prompt_format)]), timeout=60)
#      77     index = rankSelect.rank_index
#      78     # 判断index是否是0，1，2，3，  如果不是返回-1
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/asyncio/tasks.py:520, in wait_for(fut, timeout)
#     517         raise TimeoutError from exc
#     519 async with timeouts.timeout(timeout):
# --> 520     return await fut
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/retry.py:225, in RunnableRetry.ainvoke(self, input, config, **kwargs)
#     221 @override
#     222 async def ainvoke(
#     223     self, input: Input, config: RunnableConfig | None = None, **kwargs: Any
#     224 ) -> Output:
# --> 225     return await self._acall_with_config(self._ainvoke, input, config, **kwargs)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2101, in Runnable._acall_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2097     with set_config_context(child_config) as context:
#    2098         coro = acall_func_with_variable_args(
#    2099             func, input_, config, run_manager, **kwargs
#    2100         )
# -> 2101         output: Output = await coro_with_context(coro, context)
#    2102 except BaseException as e:
#    2103     await run_manager.on_chain_error(e)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/retry.py:210, in RunnableRetry._ainvoke(self, input_, run_manager, config, **kwargs)
#     203 async def _ainvoke(
#     204     self,
#     205     input_: Input,
#    (...)    208     **kwargs: Any,
#     209 ) -> Output:
# --> 210     async for attempt in self._async_retrying(reraise=True):
#     211         with attempt:
#     212             result = await super().ainvoke(
#     213                 input_,
#     214                 self._patch_config(config, run_manager, attempt.retry_state),
#     215                 **kwargs,
#     216             )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:166, in AsyncRetrying.__anext__(self)
#     164 async def __anext__(self) -> AttemptManager:
#     165     while True:
# --> 166         do = await self.iter(retry_state=self._retry_state)
#     167         if do is None:
#     168             raise StopAsyncIteration
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     151 result = None
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/retry.py:212, in RunnableRetry._ainvoke(self, input_, run_manager, config, **kwargs)
#     210 async for attempt in self._async_retrying(reraise=True):
#     211     with attempt:
# --> 212         result = await super().ainvoke(
#     213             input_,
#     214             self._patch_config(config, run_manager, attempt.retry_state),
#     215             **kwargs,
#     216         )
#     217     if attempt.retry_state.outcome and not attempt.retry_state.outcome.failed:
#     218         attempt.retry_state.set_result(result)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5547, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5540 @override
#    5541 async def ainvoke(
#    5542     self,
#    (...)   5545     **kwargs: Any | None,
#    5546 ) -> Output:
# -> 5547     return await self.bound.ainvoke(
#    5548         input,
#    5549         self._merge_configs(config),
#    5550         **{**self.kwargs, **kwargs},
#    5551     )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3169, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    3167             else:
#    3168                 part = functools.partial(step.ainvoke, input_, config)
# -> 3169             input_ = await coro_with_context(part(), context, create_task=True)
#    3170     # finish the root run
#    3171 except BaseException as e:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5547, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5540 @override
#    5541 async def ainvoke(
#    5542     self,
#    (...)   5545     **kwargs: Any | None,
#    5546 ) -> Output:
# -> 5547     return await self.bound.ainvoke(
#    5548         input,
#    5549         self._merge_configs(config),
#    5550         **{**self.kwargs, **kwargs},
#    5551     )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:405, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     395 @override
#     396 async def ainvoke(
#     397     self,
#    (...)    402     **kwargs: Any,
#     403 ) -> AIMessage:
#     404     config = ensure_config(config)
# --> 405     llm_result = await self.agenerate_prompt(
#     406         [self._convert_input(input)],
#     407         stop=stop,
#     408         callbacks=config.get("callbacks"),
#     409         tags=config.get("tags"),
#     410         metadata=config.get("metadata"),
#     411         run_name=config.get("run_name"),
#     412         run_id=config.pop("run_id", None),
#     413         **kwargs,
#     414     )
#     415     return cast(
#     416         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     417     )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1112, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1103 @override
#    1104 async def agenerate_prompt(
#    1105     self,
#    (...)   1109     **kwargs: Any,
#    1110 ) -> LLMResult:
#    1111     prompt_messages = [p.to_messages() for p in prompts]
# -> 1112     return await self.agenerate(
#    1113         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1114     )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1032, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1019 run_managers = await callback_manager.on_chat_model_start(
#    1020     self._serialized,
#    1021     messages_to_trace,
#    (...)   1026     run_id=run_id,
#    1027 )
#    1029 input_messages = [
#    1030     _normalize_messages(message_list) for message_list in messages
#    1031 ]
# -> 1032 results = await asyncio.gather(
#    1033     *[
#    1034         self._agenerate_with_cache(
#    1035             m,
#    1036             stop=stop,
#    1037             run_manager=run_managers[i] if run_managers else None,
#    1038             **kwargs,
#    1039         )
#    1040         for i, m in enumerate(input_messages)
#    1041     ],
#    1042     return_exceptions=True,
#    1043 )
#    1044 exceptions = []
#    1045 for i, res in enumerate(results):
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1323, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1321     result = generate_from_stream(iter(chunks))
#    1322 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1323     result = await self._agenerate(
#    1324         messages, stop=stop, run_manager=run_manager, **kwargs
#    1325     )
#    1326 else:
#    1327     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1509, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#    1507 payload.pop("stream")
#    1508 try:
# -> 1509     raw_response = await self.root_async_client.chat.completions.with_raw_response.parse(  # noqa: E501
#    1510         **payload
#    1511     )
#    1512     response = raw_response.parse()
#    1513 except openai.BadRequestError as e:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:381, in async_to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     377 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     379 kwargs["extra_headers"] = extra_headers
# --> 381 return cast(LegacyAPIResponse[R], await func(*args, **kwargs))
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1630, in AsyncCompletions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1623 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#    1624     return _parse_chat_completion(
#    1625         response_format=response_format,
#    1626         chat_completion=raw_completion,
#    1627         input_tools=tools,
#    1628     )
# -> 1630 return await self._post(
#    1631     "/chat/completions",
#    1632     body=await async_maybe_transform(
#    1633         {
#    1634             "messages": messages,
#    1635             "model": model,
#    1636             "audio": audio,
#    1637             "frequency_penalty": frequency_penalty,
#    1638             "function_call": function_call,
#    1639             "functions": functions,
#    1640             "logit_bias": logit_bias,
#    1641             "logprobs": logprobs,
#    1642             "max_completion_tokens": max_completion_tokens,
#    1643             "max_tokens": max_tokens,
#    1644             "metadata": metadata,
#    1645             "modalities": modalities,
#    1646             "n": n,
#    1647             "parallel_tool_calls": parallel_tool_calls,
#    1648             "prediction": prediction,
#    1649             "presence_penalty": presence_penalty,
#    1650             "prompt_cache_key": prompt_cache_key,
#    1651             "reasoning_effort": reasoning_effort,
#    1652             "response_format": _type_to_response_format(response_format),
#    1653             "safety_identifier": safety_identifier,
#    1654             "seed": seed,
#    1655             "service_tier": service_tier,
#    1656             "store": store,
#    1657             "stop": stop,
#    1658             "stream": False,
#    1659             "stream_options": stream_options,
#    1660             "temperature": temperature,
#    1661             "tool_choice": tool_choice,
#    1662             "tools": tools,
#    1663             "top_logprobs": top_logprobs,
#    1664             "top_p": top_p,
#    1665             "user": user,
#    1666             "verbosity": verbosity,
#    1667             "web_search_options": web_search_options,
#    1668         },
#    1669         completion_create_params.CompletionCreateParams,
#    1670     ),
#    1671     options=make_request_options(
#    1672         extra_headers=extra_headers,
#    1673         extra_query=extra_query,
#    1674         extra_body=extra_body,
#    1675         timeout=timeout,
#    1676         post_parser=parser,
#    1677     ),
#    1678     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#    1679     # in the `parser` function above
#    1680     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#    1681     stream=False,
#    1682 )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/openai/_base_client.py:1529, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1527 response = None
#    1528 try:
# -> 1529     response = await self._client.send(
#    1530         request,
#    1531         stream=stream or self._should_stream_response_body(request=request),
#    1532         **kwargs,
#    1533     )
#    1534 except httpx.TimeoutException as err:
#    1535     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/http_proxy.py:343, in AsyncTunnelHTTPConnection.handle_async_request(self, request)
#     336             self._connection = AsyncHTTP11Connection(
#     337                 origin=self._remote_origin,
#     338                 stream=stream,
#     339                 keepalive_expiry=self._keepalive_expiry,
#     340             )
#     342         self._connected = True
# --> 343 return await self._connection.handle_async_request(request)
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     134     async with Trace("response_closed", logger, request) as trace:
#     135         await self._response_closed()
# --> 136 raise exc
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/http11.py:106, in AsyncHTTP11Connection.handle_async_request(self, request)
#      95     pass
#      97 async with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = await self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/http11.py:177, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = await self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_async/http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/httpcore/_backends/anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/anyio/streams/tls.py:237, in TLSStream.receive(self, max_bytes)
#     236 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 237     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     238     if not data:
#     239         raise EndOfStream
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/anyio/streams/tls.py:180, in TLSStream._call_sslobject_method(self, func, *args)
#     177     if self._write_bio.pending:
#     178         await self.transport_stream.send(self._write_bio.read())
# --> 180     data = await self.transport_stream.receive()
#     181 except EndOfStream:
#     182     self._read_bio.write_eof()
#
# File ~/workplace/project/hub/sku_match/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1263, in SocketStream.receive(self, max_bytes)
#    1257 if (
#    1258     not self._protocol.read_event.is_set()
#    1259     and not self._transport.is_closing()
#    1260     and not self._protocol.is_at_eof
#    1261 ):
#    1262     self._transport.resume_reading()
# -> 1263     await self._protocol.read_event.wait()
#    1264     self._transport.pause_reading()
#    1265 else:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:

# %%
error_rows.head()
# Out:
#              商品ID                                     商品名称           规格  \
# 876   22638784830             百事食品 乐事 得克萨斯烧烤味原切马铃薯片 135g_袋      135g*1袋
# 975   22636916951                   小滑头 素食经典薄辣片调味面制品 18g_袋       18g*1袋
# 2620  22639486253                           NL8420狂神兵乓球6只装       10克*1份
# 3688  22639245179  多场景可用！透明胶带1卷 4.5厘米60米快递打包封口胶带强粘性封箱胶带宽胶带       透明胶带1卷
# 4153  22638376764             纳米双面胶一卷 透明防水无痕耐高温亚克力胶带水洗魔力胶带  厚2mm宽3CM长1M
#
#                  条码    折扣价     原价         活动  销售 店内一级分类 店内二级分类  ... 三级分类json  \
# 876   6924743924147  12.50  12.50        NaN   0   休闲零食     全部  ...      NaN
# 975   6928822300358   0.01   0.89  0.11折 限1份   6   肉干辣条     全部  ...      NaN
# 2620  6933509184206  11.24  11.24        NaN   0   运动游泳     全部  ...      NaN
# 3688            NaN   4.97   4.97        NaN   0   行李收纳     全部  ...      NaN
# 4153            NaN   4.18   4.18        NaN   0   办公学习     全部  ...      NaN
#
#       tag  美团一级分类  美团二级分类  美团三级分类        skuid  \
# 876   NaN     NaN     NaN   薯片/薯条  41432253268
# 975   NaN     NaN     NaN    面筋制品  41431660476
# 2620  NaN     NaN     NaN      球类  41431531063
# 3688  NaN     NaN     NaN      胶带  41431370651
# 4153  NaN     NaN     NaN      胶带  41431453523
#
#                                            相似商品1（ID-名称）  \
# 876   Pandas(商品ID='21400214587', 商品名称="百事食品乐事Lay's 青...
# 975   Pandas(商品ID='22528543585', 商品名称='佳龙 甜辣味五谷杂粮调味面...
# 2620  Pandas(商品ID='21148974841', 商品名称='杰士邦 零感超薄沁薄避孕套...
# 3688  Pandas(商品ID='10907345890', 商品名称='45米大号 封箱胶带 透明...
# 4153  Pandas(商品ID='10906639907', 商品名称='强力透明胶带 水洗无痕透明...
#
#                                            相似商品2（ID-名称）  \
# 876   Pandas(商品ID='10908897246', 商品名称='乐事 得克萨斯烧烤味 40...
# 975   Pandas(商品ID='21605348637', 商品名称='霸王丝 辣丝青豆辣丝 18...
# 2620                                                NaN
# 3688  Pandas(商品ID='10908591309', 商品名称='200米大号 封箱胶带 透...
# 4153  Pandas(商品ID='10908897204', 商品名称='3M双面胶汽车用强力耐高温...
#
#                                            相似商品3（ID-名称）   相似商品
# 876   Pandas(商品ID='22482849173', 商品名称="百事食品乐事Lay's 黄...  error
# 975                                                 NaN  error
# 2620                                                NaN  error
# 3688  Pandas(商品ID='10907345890', 商品名称='45米大号 封箱胶带 透明...  error
# 4153  Pandas(商品ID='17986344253', 商品名称='【贴对联专用胶带】双面胶透...  error
#
# [5 rows x 29 columns]

# %%
# 导出结果excel
error_rows.to_excel("../../output/补充Top3相似商品d1b5681b-df78-438e-9371-df272cb4f633_error.xlsx", index=False)

# %%
import asyncio
import pandas as pd
from llm_match import process_llm_row, llm_rank

async def handle_error_row(index, row, limiter, error_rows):
    print(f"正在处理错误记录：{index} - {row['商品名称']}")
    
    await limiter.record_call(800)  # 限流

    # 解析相似商品
    similar_product1 = pandas_str_to_series(row['相似商品1（ID-名称）'])
    similar_product2 = pandas_str_to_series(row['相似商品2（ID-名称）'])
    similar_product3 = pandas_str_to_series(row['相似商品3（ID-名称）'])

    # 获取商品名称
    top1 = similar_product1['商品名称'] if similar_product1 is not None else ""
    top2 = similar_product2['商品名称'] if similar_product2 is not None else ""
    top3 = similar_product3['商品名称'] if similar_product3 is not None else ""

    # 模型匹配
    idx = await llm_rank(row.商品名称, top1, top2, top3)
    print(f"匹配结果：{idx}")

    # 更新 DataFrame
    if idx == 1:
        error_rows.at[index, '相似商品'] = row['相似商品1（ID-名称）']
    elif idx == 2:
        error_rows.at[index, '相似商品'] = row['相似商品2（ID-名称）']
    elif idx == 3:
        error_rows.at[index, '相似商品'] = row['相似商品3（ID-名称）']
    elif idx == 0:
        error_rows.at[index, '相似商品'] = None
    else:
        error_rows.at[index, '相似商品'] = 'error'
        print("匹配结果错误")

async def process_error_rows(error_rows, limiter, batch_size=10):
    tasks = []
    for index, row in error_rows.iterrows():
        tasks.append(handle_error_row(index, row, limiter, error_rows))

        # 分批提交任务，避免一次性提交过多协程
        if len(tasks) >= batch_size:
            await asyncio.gather(*tasks)
            tasks = []

    # 处理剩余的任务
    if tasks:
        await asyncio.gather(*tasks)

# 调用方式
# asyncio.run(process_error_rows(error_rows, limiter))

# %%
await process_error_rows(error_rows, limiter)
# Out:
# 正在处理错误记录：975 - 小滑头 素食经典薄辣片调味面制品 18g_袋
# 正在处理错误记录：5130 - 牛皮纸袋手提袋 多规格可选打包外卖餐饮袋服装袋送人礼品袋
# 正在处理： 小滑头 素食经典薄辣片调味面制品 18g_袋
# 正在处理： 牛皮纸袋手提袋 多规格可选打包外卖餐饮袋服装袋送人礼品袋
# 匹配结果：2
# 匹配结果：3

# %%
error_rows
# Out:
#              商品ID                                           商品名称  \
# 349   22636833600                            北冰洋橙汁汽水 330毫升6听 塑包装
# 500   22636514957                    维他奶 0胆固醇低脂无负担原味豆奶 250ml6盒_提
# 559   22640208359                          粮小子福乐回头 蓝莓牛奶味面包 80g_袋
# 604   22637353101                    百草味 固形物不低于60%水果捞黄桃罐头 312g_罐
# 876   22638784830                   百事食品 乐事 得克萨斯烧烤味原切马铃薯片 135g_袋
# 975   22636916951                         小滑头 素食经典薄辣片调味面制品 18g_袋
# 1039  22639803069                               劲仔 糖醋味深海小鱼 12g_袋
# 1054  22653446605                              周长江 小豆条豆制熟食 16g_袋
# 1324  22639891009                  陶华碧老干妈 固形物不低于50%风味鸡油辣椒 280g_瓶
# 1426  22639020443                       维达Vinda 3层超韧系列纸面巾 130抽_袋
# 1641  22640091288                自由点FREPWORE M-L码超薄棉柔益生菌安睡裤 2片_包
# 1649  22640566006                             苏菲 M超薄款超熟睡安心裤 5条_包
# 1872  22638576255     红葱 手机直播支架1个 2.1米伸缩三脚架支架摄影灯架三脚架+小云台+手机夹+收纳袋
# 2278  22637706467                               龙虎 黄柏花露水 180ml_瓶
# 2313  22636678830  ins风凯蒂猫印花睡衣一套尺码可选 卡通萌宠睡衣长袖长裤可外穿甜美少女居家高颜值睡衣套装~
# 2620  22639486253                                 NL8420狂神兵乓球6只装
# 3688  22639245179        多场景可用！透明胶带1卷 4.5厘米60米快递打包封口胶带强粘性封箱胶带宽胶带
# 3901  22638141778        老山檀香线香20克_盒 沉香线香檀香家用香薰办公室喝茶插香静心写字画画香薰佛香
# 4013  22637319891         家用厚款床边地毯纯色规格可选 卧室满铺客厅茶几网红飘窗毛毛绒简约时尚渐变地垫
# 4064  22804342486                              可爱啦布布装饰摆件_个 款式随机发
# 4094  22640280275                 圆形网格笔筒学生办公桌笔筒创意时尚多功能笔筒笔桶桌面收纳盒~
# 4153  22638376764                   纳米双面胶一卷 透明防水无痕耐高温亚克力胶带水洗魔力胶带
# 4280  22639404088             马利 水粉画颜料216淡黄色100ml_瓶 马利水粉颜料瓶装马力颜料
# 4963  22640562409     十月结晶 一次性棉签耳勺签螺旋头宝宝专用两用棉签掏耳鼻屎新生儿童棉签 200支_盒X
# 5130  22639454784                   牛皮纸袋手提袋 多规格可选打包外卖餐饮袋服装袋送人礼品袋
# 5207  22638862811         【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子
# 5221  22636398481        【经久耐烧】 烧烤炭高温无烟耐烧烧烤碳家用取暖炭无烟碳果木炭易燃无烟 5斤_箱
# 5248  22637783953                迷你烧烤炉 户外折叠烧烤架子 家用60cm烧烤炉（带碳板）_台
# 5296  22639523589              蜡笔小新屁屁灯盲盒手办潮玩解压公仔摆件小夜灯1个 树脂工艺品小礼品
# 5351  22638033479      儿童马卡龙色海洋球7cm_个 彩色波波球玩具游乐场商场宝宝彩色球洗澡玩具球儿童玩具
#
#                                                      规格             条码    折扣价  \
# 349                                            330毫升*6听  6972020770178  30.00
# 500                                            250ml*6盒  4891028700074  67.00
# 559                                              80g*1袋  6950140300253   2.80
# 604                                             312g*1罐  6948939666642  13.92
# 876                                             135g*1袋  6924743924147  12.50
# 975                                              18g*1袋  6928822300358   0.01
# 1039                                                NaN  6951957205793   1.46
# 1054                                             16g*1袋  6927301200486   0.77
# 1324                                            280g*1瓶  6921804700795  11.90
# 1426                                            130抽*1袋  6901236341582   4.40
# 1641                                              2片*1包  6926052515764   9.90
# 1649                                              5条*1包  6934660550008  21.75
# 1872                                                 套装            NaN  37.28
# 2278                                           180ml*1瓶  6905218883008  14.65
# 2313  2XL【建议130-150斤】#M【建议80-100斤】#L【建议100-115斤】#XL【...            NaN  48.17
# 2620                                             10克*1份  6933509184206  11.24
# 3688                                             透明胶带1卷            NaN   4.97
# 3901                                            老山檀香#艾草            NaN   3.49
# 4013              渐变浅灰60*160cm#渐变浅灰40*60cm#渐变浅灰80*200cm            NaN  32.11
# 4064                                                NaN            NaN   0.01
# 4094                                         圆形-颜色随机-1个            NaN   3.67
# 4153                                        厚2mm宽3CM长1M            NaN   4.18
# 4280                                         淡黄色100ml/瓶  6931818013811   6.70
# 4963                                             200支/盒  6954864719797  10.02
# 5130  4号竖29长*12.5侧*38高#1号竖14.5长*10侧*19.5高#3号竖25长*12侧...  6973492670331   2.18
# 5207                                              野餐小板凳            NaN  29.31
# 5221                                           2500g*1箱            NaN  27.94
# 5248                                         60*22*33cm            NaN  36.88
# 5296                                 8*7.5*11.5cm蜡笔小新1个  6974451623009  33.55
# 5351                                           海洋球1个7cm            NaN   0.32
#
#          原价         活动  销售 店内一级分类   店内二级分类  ... 三级分类json  tag  美团一级分类  美团二级分类  \
# 349   30.00        NaN   0   饮料专区       全部  ...      NaN  NaN     NaN     NaN
# 500   67.00        NaN   0   牛奶乳品       全部  ...      NaN  NaN     NaN     NaN
# 559    2.80        NaN   1   面包糕点     蛋糕糕点  ...      NaN  NaN     NaN     NaN
# 604   14.20        NaN   0   泡面速食       全部  ...      NaN  NaN     NaN     NaN
# 876   12.50        NaN   0   休闲零食       全部  ...      NaN  NaN     NaN     NaN
# 975    0.89  0.11折 限1份   6   肉干辣条       全部  ...      NaN  NaN     NaN     NaN
# 1039   1.49        NaN   0   肉干辣条       全部  ...      NaN  NaN     NaN     NaN
# 1054   0.79        NaN   3   肉干辣条       全部  ...      NaN  NaN     NaN     NaN
# 1324  15.89        NaN   1   粮油调味       全部  ...      NaN  NaN     NaN     NaN
# 1426   4.49        NaN   0   生活用纸       全部  ...      NaN  NaN     NaN     NaN
# 1641  17.31        NaN   2   女性护理  安心裤/安睡裤  ...      NaN  NaN     NaN     NaN
# 1649  21.75        NaN   0   女性护理  安心裤/安睡裤  ...      NaN  NaN     NaN     NaN
# 1872  37.28        NaN   0   数码配件       全部  ...      NaN  NaN     NaN     NaN
# 2278  14.65        NaN   0   灭虫驱蚊       全部  ...      NaN  NaN     NaN     NaN
# 2313  48.17        NaN   0   男女服饰       全部  ...      NaN  NaN     NaN     NaN
# 2620  11.24        NaN   0   运动游泳       全部  ...      NaN  NaN     NaN     NaN
# 3688   4.97        NaN   0   行李收纳       全部  ...      NaN  NaN     NaN     NaN
# 3901   3.49        NaN   0   日用百货       全部  ...      NaN  NaN     NaN     NaN
# 4013  32.11        NaN   0   日用百货       全部  ...      NaN  NaN     NaN     NaN
# 4064   5.99  0.02折 限1份   0   日用百货       全部  ...      NaN  NaN     NaN     NaN
# 4094   3.67        NaN   0   办公学习       全部  ...      NaN  NaN     NaN     NaN
# 4153   4.18        NaN   0   办公学习       全部  ...      NaN  NaN     NaN     NaN
# 4280   6.70        NaN   0   办公学习       全部  ...      NaN  NaN     NaN     NaN
# 4963  10.02        NaN   0   母婴用品       全部  ...      NaN  NaN     NaN     NaN
# 5130   2.18        NaN   0   节庆礼品       全部  ...      NaN  NaN     NaN     NaN
# 5207  29.31        NaN   0   野炊垂钓     鱼竿渔具  ...      NaN  NaN     NaN     NaN
# 5221  27.94        NaN   0   野炊垂钓     野炊烧烤  ...      NaN  NaN     NaN     NaN
# 5248  36.88        NaN   0   野炊垂钓     户外露营  ...      NaN  NaN     NaN     NaN
# 5296  33.55        NaN   0   棋牌玩具       全部  ...      NaN  NaN     NaN     NaN
# 5351   0.32        NaN   0   棋牌玩具       全部  ...      NaN  NaN     NaN     NaN
#
#            美团三级分类        skuid  \
# 349          碳酸饮料  41428346449
# 500     植物/复合蛋白饮料  41430928016
# 559            面包  41430470543
# 604          水果罐头  41430022160
# 876         薯片/薯条  41432253268
# 975          面筋制品  41431660476
# 1039        鱼肉类制品  41428632870
# 1054          豆制品  41451588320
# 1324           辣酱  41431262747
# 1426           抽纸  41430983027
# 1641        裤型卫生巾  41431698592
# 1649        裤型卫生巾  41432087510
# 1872         手机支架  41431288778
# 2278          花露水  41431488932
# 2313     睡衣/家居服套装  41429426288
# 2620           球类  41431531063
# 3688           胶带  41431370651
# 3901           香薰  41429358274
# 4013        地垫/地毯  41430419290
# 4064         饰品摆件  41842725624
# 4094           笔筒  41430420267
# 4153           胶带  41431453523
# 4280         绘画颜料  41430526773
# 4963      儿童棉签/棉棒  41431647560
# 5130         礼品包装  41431924139
# 5207         钓箱钓椅  41431366997
# 5221         烧烤用品  41429856452
# 5248         烧烤用具  41431131374
# 5296           盲盒  41428906266
# 5351  健身玩具/户外游乐设施  41430331641
#
#                                            相似商品1（ID-名称）  \
# 349   Pandas(商品ID='10907427129', 商品名称='【6瓶装】雪碧 清爽柠檬味...
# 500   Pandas(商品ID='10908897630', 商品名称='维他奶 巧克力味豆奶饮料 ...
# 559   Pandas(商品ID='12282018058', 商品名称='福乐回头 3+2紫米夹心面...
# 604   Pandas(商品ID='18286159538', 商品名称='欢乐家 黄桃罐头 460g...
# 876   Pandas(商品ID='21400214587', 商品名称="百事食品乐事Lay's 青...
# 975   Pandas(商品ID='22528543585', 商品名称='佳龙 甜辣味五谷杂粮调味面...
# 1039  Pandas(商品ID='11025282035', 商品名称='劲仔小鱼 深海小鱼糖醋味 ...
# 1054  Pandas(商品ID='11998560831', 商品名称='味芝元 香辣鱼尾 16g_...
# 1324  Pandas(商品ID='10908360026', 商品名称='老干妈 风味鸡油辣椒 28...
# 1426  Pandas(商品ID='10908978843', 商品名称='维达抽纸3层130抽6包超...
# 1641  Pandas(商品ID='17670490923', 商品名称='【自由点】安睡裤绵柔贴身柔...
# 1649  Pandas(商品ID='21666800816', 商品名称='苏菲 XL码超薄款超熟睡安...
# 1872  Pandas(商品ID='17120016985', 商品名称='【杆约1.7米】Z6便携式...
# 2278  Pandas(商品ID='15018138500', 商品名称='【单瓶】润本喷雾花露水止痒...
# 2313  Pandas(商品ID='10906519973', 商品名称='睡衣女短袖新款夏宽松套装可...
# 2620  Pandas(商品ID='21148974841', 商品名称='杰士邦 零感超薄沁薄避孕套...
# 3688  Pandas(商品ID='10907345890', 商品名称='45米大号 封箱胶带 透明...
# 3901  Pandas(商品ID='10907426608', 商品名称='红色果香 香薰蜡烛家用精美...
# 4013  Pandas(商品ID='10908743352', 商品名称='加厚地毯客厅卧室床边毯少女...
# 4064  Pandas(商品ID='17001725005', 商品名称='万圣节装饰摆件手提南瓜灯萬...
# 4094  Pandas(商品ID='15270452832', 商品名称='ins时尚创意斜插笔筒学生...
# 4153  Pandas(商品ID='10906639907', 商品名称='强力透明胶带 水洗无痕透明...
# 4280  Pandas(商品ID='10908435372', 商品名称='马利（钛白)丙烯颜料100...
# 4963  Pandas(商品ID='10908897182', 商品名称='小瀚仔  婴儿棉签新生儿童...
# 5130  Pandas(商品ID='15370178358', 商品名称='牛皮纸袋礼品袋服装袋带手提...
# 5207  Pandas(商品ID='15379115063', 商品名称='【颜色可选】大号月亮椅户外...
# 5221  Pandas(商品ID='10909240520', 商品名称='【整箱】上烤佳 烧烤碳木炭...
# 5248  Pandas(商品ID='10908591067', 商品名称='志高 手持家用小型便携式折...
# 5296  Pandas(商品ID='15018175162', 商品名称='小羊公仔白色43cm外贸羊...
# 5351                                                NaN
#
#                                            相似商品2（ID-名称）  \
# 349   Pandas(商品ID='19951061439', 商品名称='麒麟 11°P一番搾啤酒 ...
# 500   Pandas(商品ID='19163529377', 商品名称='维他奶 原味豆奶 早餐奶 ...
# 559   Pandas(商品ID='20731286023', 商品名称='迪味臻 泡椒凤爪山椒味 8...
# 604   Pandas(商品ID='18286159538', 商品名称='欢乐家 黄桃罐头 460g...
# 876   Pandas(商品ID='10908897246', 商品名称='乐事 得克萨斯烧烤味 40...
# 975   Pandas(商品ID='21605348637', 商品名称='霸王丝 辣丝青豆辣丝 18...
# 1039  Pandas(商品ID='11023957514', 商品名称='劲仔小鱼 深海小鱼烧烤味 ...
# 1054  Pandas(商品ID='20396363876', 商品名称='缺牙齿 香辣味素牛肚 16...
# 1324  Pandas(商品ID='10908360026', 商品名称='老干妈 风味鸡油辣椒 28...
# 1426  Pandas(商品ID='12010882438', 商品名称='维达 超韧抽纸纸巾 抽取面...
# 1641  Pandas(商品ID='21993823145', 商品名称='自由点 无感无忧240mm...
# 1649  Pandas(商品ID='22504766686', 商品名称='【5包特惠】苏菲SOFY ...
# 1872  Pandas(商品ID='10908436331', 商品名称='手机支架直播支架多功能拍照...
# 2278  Pandas(商品ID='18362649484', 商品名称='怡宝 饮用纯净水 350m...
# 2313  Pandas(商品ID='22456841913', 商品名称='ins少女感KT猫睡衣女款...
# 2620                                                NaN
# 3688  Pandas(商品ID='10908591309', 商品名称='200米大号 封箱胶带 透...
# 3901                                                NaN
# 4013  Pandas(商品ID='10908591277', 商品名称='抽纸盒家用创意纸巾盒多功能...
# 4064  Pandas(商品ID='15018251120', 商品名称='汽车挂钩 可爱花朵车用椅背...
# 4094  Pandas(商品ID='10908552632', 商品名称='得力 9172得力笔筒圆形...
# 4153  Pandas(商品ID='10908897204', 商品名称='3M双面胶汽车用强力耐高温...
# 4280  Pandas(商品ID='10908201317', 商品名称='马利(土黄)牌丙烯颜料10...
# 4963  Pandas(商品ID='13351205036', 商品名称='小瀚仔 婴幼儿棉签新生儿童...
# 5130  Pandas(商品ID='15361650042', 商品名称='横版牛皮纸袋 服装袋 牛皮...
# 5207  Pandas(商品ID='10908590251', 商品名称='户外折叠椅桌椅套装折叠写生...
# 5221  Pandas(商品ID='13432183561', 商品名称='展艺 铝箔锡纸30cm10...
# 5248  Pandas(商品ID='10908436831', 商品名称='扬子家用吸尘器新款手持大功...
# 5296  Pandas(商品ID='10908200598', 商品名称='小奶龙捏捏乐慢回弹解压神器...
# 5351                                                NaN
#
#                                            相似商品3（ID-名称）  \
# 349   Pandas(商品ID='21309388195', 商品名称='胖东来 12°P精酿小麦啤...
# 500   Pandas(商品ID='19163726972', 商品名称='【单盒】维他奶原味豆奶25...
# 559   Pandas(商品ID='10906992864', 商品名称='嘉顿 牛奶味威化饼干 20...
# 604   Pandas(商品ID='18803074679', 商品名称='欢乐家 黄桃罐头 900g...
# 876   Pandas(商品ID='22482849173', 商品名称="百事食品乐事Lay's 黄...
# 975                                                 NaN
# 1039  Pandas(商品ID='11023957514', 商品名称='劲仔小鱼 深海小鱼烧烤味 ...
# 1054  Pandas(商品ID='20396363876', 商品名称='缺牙齿 香辣味素牛肚 16...
# 1324  Pandas(商品ID='10908744389', 商品名称='老干妈 风味豆豉油制辣椒 ...
# 1426  Pandas(商品ID='17852133347', 商品名称='【山姆】MM 经典纸面巾 ...
# 1641  Pandas(商品ID='10908435507', 商品名称='乐而雅晚安裤卫生巾M-L码...
# 1649  Pandas(商品ID='22504766686', 商品名称='【5包特惠】苏菲SOFY ...
# 1872  Pandas(商品ID='19123401115', 商品名称='黔云景帝350数码相机微单...
# 2278  Pandas(商品ID='21583082238', 商品名称='娃哈哈 饮用纯净水 596...
# 2313  Pandas(商品ID='15018137353', 商品名称='夏季基础款打底小吊带【颜色...
# 2620                                                NaN
# 3688  Pandas(商品ID='10907345890', 商品名称='45米大号 封箱胶带 透明...
# 3901                                                NaN
# 4013  Pandas(商品ID='10908319009', 商品名称='白色 抽纸盒家用创意纸巾盒...
# 4064  Pandas(商品ID='17626178347', 商品名称='圣诞装饰 网红拍照可爱闪光...
# 4094  Pandas(商品ID='10908591277', 商品名称='抽纸盒家用创意纸巾盒多功能...
# 4153  Pandas(商品ID='17986344253', 商品名称='【贴对联专用胶带】双面胶透...
# 4280  Pandas(商品ID='10908743078', 商品名称='马利（455湖蓝）丙烯颜料...
# 4963  Pandas(商品ID='10908480579', 商品名称='SINWUAS 古旭 棉签...
# 5130  Pandas(商品ID='17459389745', 商品名称='【牛皮纸】加厚牛皮纸袋礼品...
# 5207  Pandas(商品ID='16945874073', 商品名称='月亮躺椅靠背户外折叠椅旅行...
# 5221  Pandas(商品ID='10908743370', 商品名称='固体酒精块耐烧火锅燃料无烟...
# 5248  Pandas(商品ID='15018737627', 商品名称='围炉煮茶烤火炉烧烤架桌户外...
# 5296  Pandas(商品ID='15018140839', 商品名称='地摊大号皮卡丘公仔毛绒玩具...
# 5351                                                NaN
#
#                                                    相似商品
# 349                                                None
# 500   Pandas(商品ID='19163529377', 商品名称='维他奶 原味豆奶 早餐奶 ...
# 559                                                None
# 604                                                None
# 876                                               error
# 975                                               error
# 1039  Pandas(商品ID='11025282035', 商品名称='劲仔小鱼 深海小鱼糖醋味 ...
# 1054                                               None
# 1324                                               None
# 1426  Pandas(商品ID='10908978843', 商品名称='维达抽纸3层130抽6包超...
# 1641                                               None
# 1649  Pandas(商品ID='22504766686', 商品名称='【5包特惠】苏菲SOFY ...
# 1872  Pandas(商品ID='10908436331', 商品名称='手机支架直播支架多功能拍照...
# 2278                                               None
# 2313  Pandas(商品ID='22456841913', 商品名称='ins少女感KT猫睡衣女款...
# 2620                                              error
# 3688                                              error
# 3901                                               None
# 4013  Pandas(商品ID='10908743352', 商品名称='加厚地毯客厅卧室床边毯少女...
# 4064  Pandas(商品ID='17001725005', 商品名称='万圣节装饰摆件手提南瓜灯萬...
# 4094  Pandas(商品ID='10908552632', 商品名称='得力 9172得力笔筒圆形...
# 4153                                              error
# 4280                                               None
# 4963                                               None
# 5130                                              error
# 5207  Pandas(商品ID='15379115063', 商品名称='【颜色可选】大号月亮椅户外...
# 5221  Pandas(商品ID='10909240520', 商品名称='【整箱】上烤佳 烧烤碳木炭...
# 5248                                              error
# 5296                                               None
# 5351                                              error
#
# [30 rows x 29 columns]

# %%
# 将error_rows数据 按照index更新相似商品列到df中，使用at
for index, row in error_rows.iterrows():
    df.at[index, '相似商品'] = row['相似商品']

# %%
# 导出excel
df.to_excel("../../output/补充Top3相似商品retry4.xlsx", index=False)
