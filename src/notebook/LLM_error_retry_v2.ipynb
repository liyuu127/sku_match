# %% [markdown]
# 对大模型调用错误的记录进行查询，尝试进行重试

# %%
import pandas as pd


def load_excel(file_path: str) -> pd.DataFrame:
    """
    读取Excel文件，验证必要列并处理空值
    要求文件必须包含"商品ID"和"商品名称"列（可修改required_cols适配实际列名）
    """
    try:
        df = pd.read_excel(file_path, engine='openpyxl')
        required_cols = ['商品ID', '商品名称']
        # 检查必要列是否存在
        missing_cols = [col for col in required_cols if col not in df.columns]
        if missing_cols:
            raise ValueError(f"缺少必要列：{', '.join(missing_cols)}，需包含{required_cols}")
        # 去除商品ID或名称为空的无效行
        df = df.dropna(subset=required_cols).reset_index(drop=True)
        # 强制转为字符串类型，避免数字ID/名称拼接出错（如科学计数法、格式丢失）
        df['商品ID'] = df['商品ID'].astype(str).str.strip()
        df['商品名称'] = df['商品名称'].astype(str).str.strip()
        return df
    except Exception as e:
        print(f"读取文件{file_path}失败：{str(e)}")
        raise

# %%
import math
import pandas as pd
import re


def pandas_str_to_series(s) -> pd.Series:
    # s为None或""或nan
    if s is None or s == "" or (isinstance(s, float) and math.isnan(s)):
        return None

    inner = s[s.find("(") + 1: s.rfind(")")]

    pattern = re.compile(r"(\w+)=('[^']*'|[^,]*)")
    data = {k: v.strip("'") if v.strip() != "nan" else None for k, v in pattern.findall(inner)}

    # 3️⃣ 转为 DataFrame
    df = pd.DataFrame([data])
    return df.iloc[0]

# %%
# 加载数据表文件
df = load_excel("../../output/补充Top3相似商品7b5f9635-c6a9-427b-b13e-e0bfb702273a.xlsx")
df.head()
# Out:
#           商品ID  是否已打标                                商品名称  \
# 0  22639131950      0       七度空间 420mm绢爽网面透气超特长夜用卫生巾 4片_包
# 1  22652416416      1              胖东来 12°P精酿小麦啤酒 330ml_听
# 2  22639565169      0                       清风 纯水湿巾 10片_包
# 3  22637741974      0                 彩色长尾夹燕尾夹19mm(40只)_盒
# 4  22637319896      0  家有喜事喜庆红色塑料盆 结婚嫁妆大红脸盆洗脚盆红妆喜盆_个 规格可选
#
#                           规格            条码    折扣价     原价   活动  销售 店内一级分类  ...  \
# 0                      4片*1包  6.903244e+12  12.50  12.50  NaN   0   女性护理  ...
# 1                   330ml*1听  6.972529e+12   8.32   8.49  NaN   1   酒类专区  ...
# 2                     10片*1包  6.922266e+12   5.28   5.39  NaN   0   生活用纸  ...
# 3                        NaN  6.941245e+12   8.70   8.70  NaN   0   办公学习  ...
# 4  35*11.5cm#37*12cm#33*11cm  6.938576e+12   5.24   5.24  NaN   0   家庭清洁  ...
#
#   三级分类json tag  美团一级分类  美团二级分类   美团三级分类        skuid  \
# 0      NaN NaN     NaN     NaN  卫生巾/卫生棉  41432125836
# 1      NaN NaN     NaN     NaN     精酿啤酒  41454728881
# 2      NaN NaN     NaN     NaN  湿纸巾/湿厕纸  41431605679
# 3      NaN NaN     NaN     NaN       夹子  41428383687
# 4      NaN NaN     NaN     NaN    脸盆/水桶  41430419297
#
#                                         相似商品1（ID-名称）  \
# 0  Pandas(商品ID='10908978937', 商品名称='【苏菲】超熟睡柔棉感纤巧夜...
# 1  Pandas(商品ID='17448439267', 商品名称='【爆品精酿】胖东来DL 1...
# 2  Pandas(商品ID='10908591313', 商品名称='清风 柔湿巾 清风湿巾纸纯...
# 3  Pandas(商品ID='19029840765', 商品名称='得力 8552ES 41m...
# 4  Pandas(商品ID='10906639901', 商品名称='颜色随机 洗脸盆家用塑料盆...
#
#                                         相似商品2（ID-名称）  \
# 0  Pandas(商品ID='21326884399', 商品名称='苏菲420mm超熟睡柔棉感...
# 1                                                NaN
# 2                                                NaN
# 3  Pandas(商品ID='10908552330', 商品名称='得力8487长尾夹5号19...
# 4  Pandas(商品ID='10908552583', 商品名称='暗酒红色 格纹花纹男士结婚...
#
#                                         相似商品3（ID-名称）  \
# 0  Pandas(商品ID='10907930090', 商品名称='【苏菲】超熟睡超薄裸感肌夜...
# 1                                                NaN
# 2                                                NaN
# 3  Pandas(商品ID='10909128477', 商品名称='得力 彩色工字钉 35只_...
# 4  Pandas(商品ID='22419552653', 商品名称='礼花筒结婚礼炮筒开业乔迁彩...
#
#                                                 相似商品
# 0                                              error
# 1  Pandas(商品ID='17448439267', 商品名称='【爆品精酿】胖东来DL 1...
# 2  Pandas(商品ID='10908591313', 商品名称='清风 柔湿巾 清风湿巾纸纯...
# 3  Pandas(商品ID='10908552330', 商品名称='得力8487长尾夹5号19...
# 4                                                NaN
#
# [5 rows x 30 columns]

# %%
# 提取相似商品列值为error的记录，相似商品列可能为None
error_rows = df[df['相似商品'].notnull() & df['相似商品'].str.contains('error')]
error_rows
# Out:
#             商品ID  是否已打标                                        商品名称  \
# 0    22639131950      0               七度空间 420mm绢爽网面透气超特长夜用卫生巾 4片_包
# 17   22637998436      1                 元气自在水 0糖0脂红豆薏米水植物饮料 500ml_瓶
# 28   22640442876      0                         斧头牌 晶怡厨房重油污净 500g_瓶
# 31   22636514970      0     统一UNI-PRESIDENT 低糖含有茶多酚绿茶茉莉味茶饮料 500毫升_瓶
# 33   22638074364      0        重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~
# ..           ...    ...                                         ...
# 450  22639760796      0  【密封锁鲜】 白色家用饺子盒食品冰箱专用冷冻盒密封保鲜多层速冻馄饨水饺收纳盒 1_个
# 475  22637822453      0        喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套
# 478  22638628659      0             豹纹金钻辣妹穿戴甲30片_盒 高级感辣妹豹纹水钻法式手工穿戴甲
# 479  22638034168      0         假下眼睫毛纹身贴 女仿真下睫毛持久放水化妆一次性疤痕玩具防水睫毛纹身贴
# 495  22639691819      0                       晨露 沁心薰衣草气雾清新剂 320ml_瓶
#
#                           规格            条码    折扣价     原价   活动  销售 店内一级分类  ...  \
# 0                      4片*1包  6.903244e+12  12.50  12.50  NaN   0   女性护理  ...
# 17                  500ml*1瓶  6.975177e+12   6.85   6.99  NaN   0   饮料专区  ...
# 28                   500g*1瓶  6.920722e+12  19.35  19.35  NaN   0   家庭清洁  ...
# 31                  500毫升*1瓶  6.925304e+12   3.42   3.49  NaN   2   饮料专区  ...
# 33   美工刀一把【内含合金刀片5枚】#合金刀片10枚           NaN  10.79  10.79  NaN   0   办公学习  ...
# ..                       ...           ...    ...    ...  ...  ..    ...  ...
# 450                     白色一层           NaN   9.29   9.29  NaN   1   厨具餐具  ...
# 475                  白色-喇叭袜套           NaN  23.37  23.37  NaN   0   内裤衣袜  ...
# 478            斑纹金钻穿戴甲#30片/盒           NaN  15.00  15.00  NaN   0   美发美甲  ...
# 479           YJM-01-10*14CM           NaN   3.82   3.82  NaN   0   美妆护肤  ...
# 495                 320ml*1瓶  6.907470e+12  13.58  13.58  NaN   0   家庭清洁  ...
#
#     三级分类json tag  美团一级分类  美团二级分类     美团三级分类        skuid  \
# 0        NaN NaN     NaN     NaN    卫生巾/卫生棉  41432125836
# 17       NaN NaN     NaN     NaN       植物饮料  41429718457
# 28       NaN NaN     NaN     NaN  多功能/万用清洁剂  41431887838
# 31       NaN NaN     NaN     NaN        茶饮料  41430928029
# 33       NaN NaN     NaN     NaN        美工刀  41431412131
# ..       ...  ..     ...     ...        ...          ...
# 450      NaN NaN     NaN     NaN        保鲜盒  41429676874
# 475      NaN NaN     NaN     NaN         袜子  41430619415
# 478      NaN NaN     NaN     NaN       美甲工具  41429595748
# 479      NaN NaN     NaN     NaN     假睫毛及工具  41431004175
# 495      NaN NaN     NaN     NaN       空气清新  41429944874
#
#                                           相似商品1（ID-名称）  \
# 0    Pandas(商品ID='10908978937', 商品名称='【苏菲】超熟睡柔棉感纤巧夜...
# 17   Pandas(商品ID='18828350974', 商品名称='元气森林 自在水 0糖0脂...
# 28   Pandas(商品ID='19842173159', 商品名称='威猛先生 厨房重油污净 5...
# 31   Pandas(商品ID='10908552830', 商品名称='统一 茉莉味绿茶 500m...
# 33   Pandas(商品ID='15019005365', 商品名称='得力 2034美工刀 不锈...
# ..                                                 ...
# 450  Pandas(商品ID='15017781650', 商品名称='【保鲜收纳盒】食品冰箱肉类...
# 475  Pandas(商品ID='15018035961', 商品名称='针织jk套袜 小腿堆堆袜 ...
# 478  Pandas(商品ID='10907426856', 商品名称='网红新款ins Hs508...
# 479  Pandas(商品ID='10907426854', 商品名称='海氏海诺 1010cm敷贴...
# 495  Pandas(商品ID='10908552833', 商品名称='日本 小林制药 柠檬厕所消...
#
#                                           相似商品2（ID-名称）  \
# 0    Pandas(商品ID='21326884399', 商品名称='苏菲420mm超熟睡柔棉感...
# 17                                                 NaN
# 28   Pandas(商品ID='15196627393', 商品名称='老管家厨房重油污清洗剂去污...
# 31                                                 NaN
# 33   Pandas(商品ID='10908978865', 商品名称='得力 金属美工刀小号裁纸壁...
# ..                                                 ...
# 450  Pandas(商品ID='17148417223', 商品名称='保鲜盒食品收纳盒塑料盒子密...
# 475  Pandas(商品ID='15018039861', 商品名称='超薄小腿袜 显瘦黑丝袜女夏...
# 478  Pandas(商品ID='10975775921', 商品名称='十月结晶 母乳保鲜袋 30...
# 479  Pandas(商品ID='12453567787', 商品名称='兔奶奶 假睫毛胶水无痕定型...
# 495  Pandas(商品ID='10908125844', 商品名称='爱家  沁心柠檬空气清新剂...
#
#                                           相似商品3（ID-名称）   相似商品
# 0    Pandas(商品ID='10907930090', 商品名称='【苏菲】超熟睡超薄裸感肌夜...  error
# 17                                                 NaN  error
# 28   Pandas(商品ID='10907345818', 商品名称='威猛先生 管道疏通剂强力溶...  error
# 31                                                 NaN  error
# 33   Pandas(商品ID='10908743392', 商品名称='得力 美工刀2041壁纸刀...  error
# ..                                                 ...    ...
# 450  Pandas(商品ID='10908552070', 商品名称='玻璃饭盒 微波炉加热专用上...  error
# 475  Pandas(商品ID='18850537564', 商品名称='JK小腿袜中高筒ins潮纯...  error
# 478  Pandas(商品ID='15018116533', 商品名称='婵朵美甲 穿戴甲手工专用甲...  error
# 479                                                NaN  error
# 495  Pandas(商品ID='10908629505', 商品名称='【单瓶】香居源 柠檬味液体...  error
#
# [84 rows x 30 columns]

# %%
# error_rows数据信息，多少行，多少列
error_rows.shape
# Out:
# (84, 30)

# %%
from Limter import RateLimiter

# 设置限流器
limiter = RateLimiter()

# %%
# 处理单条 error 记录的协程
from llm_match import process_llm_row, llm_rank


async def handle_error_row(index, row, limiter, df):

    await limiter.record_call(800)

    similar_product1 = pandas_str_to_series(row['相似商品1（ID-名称）'])
    similar_product2 = pandas_str_to_series(row['相似商品2（ID-名称）'])
    similar_product3 = pandas_str_to_series(row['相似商品3（ID-名称）'])

    top1 = similar_product1['商品名称'] if similar_product1 is not None else ""
    top2 = similar_product2['商品名称'] if similar_product2 is not None else ""
    top3 = similar_product3['商品名称'] if similar_product3 is not None else ""

    # 模型排序
    idx = await llm_rank(row.商品名称, top1, top2, top3)
    print(f"  匹配结果：{idx}")

    if idx == 1:
        df.at[index, '相似商品'] = row['相似商品1（ID-名称）']
    elif idx == 2:
        df.at[index, '相似商品'] = row['相似商品2（ID-名称）']
    elif idx == 3:
        df.at[index, '相似商品'] = row['相似商品3（ID-名称）']
    elif idx == 0:
        df.at[index, '相似商品'] = None
    else:
        df.at[index, '相似商品'] = 'error'  # 仍然是错误，等待下一轮 retry

# %%
import asyncio


# 每一轮重试协程批处理
async def run_retry_batch(df, limiter, batch_size=10):
    tasks = []
    for index, row in df.iterrows():
        # 判断是否是error记录，如果不是跳过这条记录
        if row['相似商品'] != 'error':
            continue
        tasks.append(handle_error_row(index, row, limiter, df))
        if len(tasks) >= batch_size:
            await asyncio.gather(*tasks)
            tasks = []
    if tasks:
        await asyncio.gather(*tasks)

# %%
# 循环过滤 + 重试
async def retry_error_rows(df, limiter, max_rounds=5, batch_size=10):
    """
    df: 原始 DataFrame，包含 '相似商品' 字段
    max_rounds: 最多重试几轮
    batch_size: 每次协程批处理大小
    """

    for round_num in range(1, max_rounds + 1):
        # 过滤需要 retry 的记录
        error_rows = df[df['相似商品'] == 'error']

        retry_count = len(error_rows)
        print(f"\n====== 第 {round_num} 次遍历，需重试记录：{retry_count} 条 ======")

        if retry_count == 0:
            print("所有错误记录已处理完成！")
            break

        await run_retry_batch(df, limiter, batch_size=batch_size)

    else:
        print("\n⚠ 达到最大重试次数，但仍有未修复的错误记录")

# %%
await retry_error_rows(df, limiter, 10, 10)
# Out:
# ====== 第 1 次遍历，需重试记录：84 条 ======
#   正在处理错误记录：0 - 七度空间 420mm绢爽网面透气超特长夜用卫生巾 4片_包
#   正在处理错误记录：17 - 元气自在水 0糖0脂红豆薏米水植物饮料 500ml_瓶
#   正在处理错误记录：28 - 斧头牌 晶怡厨房重油污净 500g_瓶
#   正在处理错误记录：31 - 统一UNI-PRESIDENT 低糖含有茶多酚绿茶茉莉味茶饮料 500毫升_瓶
#   正在处理错误记录：33 - 重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~
#   正在处理错误记录：60 - Bakerdream百钻 面包糠 100g_袋
#   正在处理错误记录：67 - 卫龙亲嘴烧 经典香辣风味调味面制品 24g_袋
#   正在处理错误记录：68 - 无漆无蜡筷子10双装_盒 无节本色竹筷吸塑盒装碳化筷子
#   正在处理错误记录：71 - 元气森林 0糖0卡0咖啡因菊花茶植物饮料 600ml_瓶
#   正在处理错误记录：83 - 得力 24色可洗水彩笔 24支_盒
# 正在处理： 七度空间 420mm绢爽网面透气超特长夜用卫生巾 4片_包
# 正在处理： 元气自在水 0糖0脂红豆薏米水植物饮料 500ml_瓶
# 正在处理： 斧头牌 晶怡厨房重油污净 500g_瓶
# 正在处理： 统一UNI-PRESIDENT 低糖含有茶多酚绿茶茉莉味茶饮料 500毫升_瓶
# 正在处理： 重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~
# 正在处理： Bakerdream百钻 面包糠 100g_袋
# 正在处理： 卫龙亲嘴烧 经典香辣风味调味面制品 24g_袋
# 正在处理： 无漆无蜡筷子10双装_盒 无节本色竹筷吸塑盒装碳化筷子
# 正在处理： 元气森林 0糖0卡0咖啡因菊花茶植物饮料 600ml_瓶
# 正在处理： 得力 24色可洗水彩笔 24支_盒
#   匹配结果：1
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
#   匹配结果：1
#   匹配结果：0
#   匹配结果：0
#   匹配结果：2
# 商品：重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~ 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 3\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
# 商品：卫龙亲嘴烧 经典香辣风味调味面制品 24g_袋 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   正在处理错误记录：84 - 东方韵味结婚请柬1个 新中式婚礼喜帖邀请函婚宴简约请帖
#   正在处理错误记录：88 - 金达日美A6401大号指甲钳颜色随机单个装
#   正在处理错误记录：91 - 千焙屋 全麦吐司调理面包 105g_袋
#   正在处理错误记录：93 - 脚踩打气筒 脚踩塑料充气泵 脚踏气球充气筒便携游泳圈打气筒一个
#   正在处理错误记录：98 - 葱伴侣 鲜甜咸香原酿豆瓣酱 300g_盒
#   正在处理错误记录：105 - 百事可乐 可乐型汽水 330ml_罐
#   正在处理错误记录：112 - 统一海之言 0脂果汁含量≥5%柠檬味电解质饮料 500ml_瓶
#   正在处理错误记录：118 - 雕牌 清新柠檬洗洁精 408g_瓶
#   正在处理错误记录：139 - 家有点点  苹果 3A2米快充数据线_MC11X
#   正在处理错误记录：143 - 汰渍Tide 柠檬清新型净白去渍洗衣粉 218g_袋
# 正在处理： 东方韵味结婚请柬1个 新中式婚礼喜帖邀请函婚宴简约请帖
# 正在处理： 金达日美A6401大号指甲钳颜色随机单个装
# 正在处理： 千焙屋 全麦吐司调理面包 105g_袋
# 正在处理： 脚踩打气筒 脚踩塑料充气泵 脚踏气球充气筒便携游泳圈打气筒一个
# 正在处理： 葱伴侣 鲜甜咸香原酿豆瓣酱 300g_盒
# 正在处理： 百事可乐 可乐型汽水 330ml_罐
# 正在处理： 统一海之言 0脂果汁含量≥5%柠檬味电解质饮料 500ml_瓶
# 正在处理： 雕牌 清新柠檬洗洁精 408g_瓶
# 正在处理： 家有点点  苹果 3A2米快充数据线_MC11X
# 正在处理： 汰渍Tide 柠檬清新型净白去渍洗衣粉 218g_袋
#   匹配结果：1
#   匹配结果：0
#   匹配结果：1
#   匹配结果：2
#   匹配结果：0
#   匹配结果：0
#   匹配结果：1
#   匹配结果：0
#   匹配结果：1
# 商品：汰渍Tide 柠檬清新型净白去渍洗衣粉 218g_袋 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   正在处理错误记录：144 - 兰康保 去渍滚珠液50ml_瓶 免水洗除油污渍清洁剂油斑点衣服便携去渍笔
#   正在处理错误记录：145 - 禄讯 3.5mm转2rca双莲花音频线1个 手机电脑音响公对公一分二rca音频线
#   正在处理错误记录：152 - 卫龙 大面筋调味面制品 102g_袋
#   正在处理错误记录：153 - 小鹿妈妈牙线旺虎50支_盒 塑料牙签弓形剔牙线盒装
#   正在处理错误记录：159 - 麻辣王子 很麻很辣地道辣条 18g_袋
#   正在处理错误记录：160 - 马桶疏通器皮搋子1个 58cm通下水道厕所神器皮搋子抽子皮吸家用通便管道地漏堵塞拔子工具
#   正在处理错误记录：161 - 装饰丝带婚礼布置气球彩带生日节日庆典装饰气球绑绳礼品包装绳10米 红色1个
#   正在处理错误记录：169 - 珍珠白直杆海绵拖把一个 家用一拖净吸水对折式胶棉地拖墩布挤水加长清洁拖把
#   正在处理错误记录：171 - 马利 水粉画颜料302大红色1瓶 100ml马利水粉颜料瓶装马力颜料
#   正在处理错误记录：173 - 【简约压圈款】深蓝色塑料垃圾桶1个 规格可选 家用大容量卫生间厨房无盖垃圾篓
# 正在处理： 兰康保 去渍滚珠液50ml_瓶 免水洗除油污渍清洁剂油斑点衣服便携去渍笔
# 正在处理： 禄讯 3.5mm转2rca双莲花音频线1个 手机电脑音响公对公一分二rca音频线
# 正在处理： 卫龙 大面筋调味面制品 102g_袋
# 正在处理： 小鹿妈妈牙线旺虎50支_盒 塑料牙签弓形剔牙线盒装
# 正在处理： 麻辣王子 很麻很辣地道辣条 18g_袋
# 正在处理： 马桶疏通器皮搋子1个 58cm通下水道厕所神器皮搋子抽子皮吸家用通便管道地漏堵塞拔子工具
# 正在处理： 装饰丝带婚礼布置气球彩带生日节日庆典装饰气球绑绳礼品包装绳10米 红色1个
# 正在处理： 珍珠白直杆海绵拖把一个 家用一拖净吸水对折式胶棉地拖墩布挤水加长清洁拖把
# 正在处理： 马利 水粉画颜料302大红色1瓶 100ml马利水粉颜料瓶装马力颜料
# 正在处理： 【简约压圈款】深蓝色塑料垃圾桶1个 规格可选 家用大容量卫生间厨房无盖垃圾篓
#   匹配结果：0
#   匹配结果：3
#   匹配结果：1
#   匹配结果：3
#   匹配结果：3
#   匹配结果：3
#   匹配结果：1
#   匹配结果：1
#   匹配结果：0
#   匹配结果：1
#   正在处理错误记录：177 - 沙宣 修护水养洗发水 200g_瓶
#   正在处理错误记录：185 - 悠宜UNNY眼线胶笔0.05g 不晕染防水持久不晕染眼线胶笔
#   正在处理错误记录：187 - 百事食品乐事Lay's 经典原味原切马铃薯片 70g_袋
#   正在处理错误记录：188 - 法丽兹 酸奶巧克力味曲奇夹心饼干 126g_盒
#   正在处理错误记录：194 - 蓝月亮洗衣液正品亮白增艳薰衣草大桶瓶装补充装3kg公斤整箱家用
#   正在处理错误记录：197 - 晨露 淡雅茉莉清香盒 100g_盒
#   正在处理错误记录：199 - 木工SK5折叠锯一个多尺寸可选 家用小型手持折叠锯园林果树户外手锯伐木锯木神器快速手工锯~
#   正在处理错误记录：210 - 金阳 圆形针线盒 约100g_盒
#   正在处理错误记录：211 - 蓝月亮 油污克星清洁剂 500g2瓶_袋
#   正在处理错误记录：213 - 贝洁森 柔纸巾婴儿乳霜纸新生儿软抽纸手帕纸面巾纸软纸巾3层40抽_包
# 正在处理： 沙宣 修护水养洗发水 200g_瓶
# 正在处理： 悠宜UNNY眼线胶笔0.05g 不晕染防水持久不晕染眼线胶笔
# 正在处理： 百事食品乐事Lay's 经典原味原切马铃薯片 70g_袋
# 正在处理： 法丽兹 酸奶巧克力味曲奇夹心饼干 126g_盒
# 正在处理： 蓝月亮洗衣液正品亮白增艳薰衣草大桶瓶装补充装3kg公斤整箱家用
# 正在处理： 晨露 淡雅茉莉清香盒 100g_盒
# 正在处理： 木工SK5折叠锯一个多尺寸可选 家用小型手持折叠锯园林果树户外手锯伐木锯木神器快速手工锯~
# 正在处理： 金阳 圆形针线盒 约100g_盒
# 正在处理： 蓝月亮 油污克星清洁剂 500g2瓶_袋
# 正在处理： 贝洁森 柔纸巾婴儿乳霜纸新生儿软抽纸手帕纸面巾纸软纸巾3层40抽_包
#   匹配结果：1
#   匹配结果：0
#   匹配结果：2
#   匹配结果：0
#   匹配结果：0
# 商品：晨露 淡雅茉莉清香盒 100g_盒 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   匹配结果：0
#   匹配结果：0
#   匹配结果：2
# 商品：金阳 圆形针线盒 约100g_盒 发生异常:
#   匹配结果：-1
#   正在处理错误记录：219 - 唛饭石奶锅小奶锅雪平锅一人食泡面锅宝宝辅食锅汤锅煎煮一体不粘锅
#   正在处理错误记录：229 - 劲仔 香辣味深海小鱼 12g_袋
#   正在处理错误记录：233 - 娃哈哈AD钙奶儿童奶含乳饮料饮品童年哇哈哈 220gx4瓶／排
#   正在处理错误记录：242 - 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
#   正在处理错误记录：246 - 乌苏 11°P乌苏啤酒罐装 500ml_听
#   正在处理错误记录：250 - 李字 电热蚊香液 45ml2瓶_盒
#   正在处理错误记录：254 - 十月结晶 宝宝吸鼻器婴儿新生掏鼻屎鼻涕鼻塞通鼻神器口吸式清洁器_个
#   正在处理错误记录：256 - 丁家宜 补水洗面奶 120g_支
#   正在处理错误记录：270 - 清扬去屑头皮护理洗发露养根韧发型175g_瓶
#   正在处理错误记录：271 - 巴黎欧莱雅 精油润养润养洗发露 200ml_瓶
# 正在处理： 唛饭石奶锅小奶锅雪平锅一人食泡面锅宝宝辅食锅汤锅煎煮一体不粘锅
# 正在处理： 劲仔 香辣味深海小鱼 12g_袋
# 正在处理： 娃哈哈AD钙奶儿童奶含乳饮料饮品童年哇哈哈 220gx4瓶／排
# 正在处理： 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
# 正在处理： 乌苏 11°P乌苏啤酒罐装 500ml_听
# 正在处理： 李字 电热蚊香液 45ml2瓶_盒
# 正在处理： 十月结晶 宝宝吸鼻器婴儿新生掏鼻屎鼻涕鼻塞通鼻神器口吸式清洁器_个
# 正在处理： 丁家宜 补水洗面奶 120g_支
# 正在处理： 清扬去屑头皮护理洗发露养根韧发型175g_瓶
# 正在处理： 巴黎欧莱雅 精油润养润养洗发露 200ml_瓶
#   匹配结果：2
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
# 商品：李字 电热蚊香液 45ml2瓶_盒 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
# 商品：冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏] 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 3\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
# 商品：乌苏 11°P乌苏啤酒罐装 500ml_听 发生异常:
#   匹配结果：-1
# 商品：娃哈哈AD钙奶儿童奶含乳饮料饮品童年哇哈哈 220gx4瓶／排 发生异常:
#   匹配结果：-1
# 商品：清扬去屑头皮护理洗发露养根韧发型175g_瓶 发生异常:
#   匹配结果：-1
#   正在处理错误记录：274 - 十月结晶 母乳储奶袋奶水保鲜储存冷冻存奶袋200ml母乳储存袋 30片装
#   正在处理错误记录：278 - 怡冠园 豆角干味面筋调味面制品 108g_袋
#   正在处理错误记录：281 - 比比赞掌心脆香酥干脆面约1.6g_包 口味随机发
#   正在处理错误记录：285 - 海底捞 麻辣牛油味脆爽牛肚自煮火锅套餐 435g_盒
#   正在处理错误记录：288 - 心相印湿厕纸99.9杀菌40片XCY040#
#   正在处理错误记录：293 - 三得利SUNTORY 沁葡水白葡萄味饮料 550ml_瓶
#   正在处理错误记录：297 - 生态澳绒床单160x200cm_袋
#   正在处理错误记录：302 - 首品染发剂 染发膏711奶茶灰棕色100ml _套 底色较浅染后就浅 赠染发工具
#   正在处理错误记录：315 - 百草味 甜辣味鸭脖 110g_袋
#   正在处理错误记录：322 - 可口可乐雪碧 清爽柠檬味(汽水) 2000ml_瓶
# 正在处理： 十月结晶 母乳储奶袋奶水保鲜储存冷冻存奶袋200ml母乳储存袋 30片装
# 正在处理： 怡冠园 豆角干味面筋调味面制品 108g_袋
# 正在处理： 比比赞掌心脆香酥干脆面约1.6g_包 口味随机发
# 正在处理： 海底捞 麻辣牛油味脆爽牛肚自煮火锅套餐 435g_盒
# 正在处理： 心相印湿厕纸99.9杀菌40片XCY040#
# 正在处理： 三得利SUNTORY 沁葡水白葡萄味饮料 550ml_瓶
# 正在处理： 生态澳绒床单160x200cm_袋
# 正在处理： 首品染发剂 染发膏711奶茶灰棕色100ml _套 底色较浅染后就浅 赠染发工具
# 正在处理： 百草味 甜辣味鸭脖 110g_袋
# 正在处理： 可口可乐雪碧 清爽柠檬味(汽水) 2000ml_瓶
#   匹配结果：1
#   匹配结果：0
#   匹配结果：1
#   匹配结果：3
#   匹配结果：0
#   匹配结果：0
# 商品：十月结晶 母乳储奶袋奶水保鲜储存冷冻存奶袋200ml母乳储存袋 30片装 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 1\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   匹配结果：2
#   匹配结果：0
#   匹配结果：0
#   正在处理错误记录：332 - 农夫山泉 饮用天然水 550ml_瓶
#   正在处理错误记录：333 - 双汇 香辣香脆肠 32g_袋
#   正在处理错误记录：336 - 黑色贴标条纹长袖T恤规格可选 儿童数字印花圆领斜肩男童宽松洋气上衣打底衫可外穿~
#   正在处理错误记录：339 - 蓝月亮 自然清香亮白增艳深层洁净护理洗衣液 1kg_桶
#   正在处理错误记录：340 - 康师傅 冰力十足冰红茶柠檬口味茶饮品 500ml_瓶
#   正在处理错误记录：341 - 顶美 削皮器 1个_件 颜色随机
#   正在处理错误记录：361 - 劲仔 酱汁味深海小鱼 12g_袋
#   正在处理错误记录：371 - 大容量太空杯学生网红运动水壶弹跳盖塑料杯茶水分离水杯1200ml_个（颜色随机）
#   正在处理错误记录：393 - 亿滋奥利奥 浓醇巧克力味夹心饼干 48.5g_袋
#   正在处理错误记录：395 - 艾草枕头 颈椎枕 艾草护颈助睡眠睡觉专用连体枕可拆卸  绿色1个
# 正在处理： 农夫山泉 饮用天然水 550ml_瓶
# 正在处理： 双汇 香辣香脆肠 32g_袋
# 正在处理： 黑色贴标条纹长袖T恤规格可选 儿童数字印花圆领斜肩男童宽松洋气上衣打底衫可外穿~
# 正在处理： 蓝月亮 自然清香亮白增艳深层洁净护理洗衣液 1kg_桶
# 正在处理： 康师傅 冰力十足冰红茶柠檬口味茶饮品 500ml_瓶
# 正在处理： 顶美 削皮器 1个_件 颜色随机
# 正在处理： 劲仔 酱汁味深海小鱼 12g_袋
# 正在处理： 大容量太空杯学生网红运动水壶弹跳盖塑料杯茶水分离水杯1200ml_个（颜色随机）
# 正在处理： 亿滋奥利奥 浓醇巧克力味夹心饼干 48.5g_袋
# 正在处理： 艾草枕头 颈椎枕 艾草护颈助睡眠睡觉专用连体枕可拆卸  绿色1个
#   匹配结果：1
#   匹配结果：1
#   匹配结果：3
#   匹配结果：0
#   匹配结果：1
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
#   匹配结果：1
#   匹配结果：1
#   正在处理错误记录：399 - 乐事 无限滋香烤肉味薯片 104g_罐
#   正在处理错误记录：404 - 雀巢咖啡 1+2意式浓醇低糖特浓即溶咖啡饮品 91g(13g7条)_盒
#   正在处理错误记录：414 - 宝中宝保湿润肤霜250g_盒
#   正在处理错误记录：420 - 怡宝Cestbon 饮用纯净水 555ml24瓶_箱
#   正在处理错误记录：422 - 网红复古凯旋门猫眼墨镜女一副 黑框灰片款防晒椭圆形太阳眼镜
#   正在处理错误记录：436 - 【USB转安卓】品胜 Micro接口安卓手机数据线 安卓充电线数据线 0.9米_条
#   正在处理错误记录：441 - 华味亨 相思梅 160克_罐
#   正在处理错误记录：445 - 家用酒精喷壶一个装颜色随机 消毒水清洁专用喷雾瓶气压式细雾浇花洒小喷水壶喷瓶~
#   正在处理错误记录：448 - 【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子
#   正在处理错误记录：450 - 【密封锁鲜】 白色家用饺子盒食品冰箱专用冷冻盒密封保鲜多层速冻馄饨水饺收纳盒 1_个
# 正在处理： 乐事 无限滋香烤肉味薯片 104g_罐
# 正在处理： 雀巢咖啡 1+2意式浓醇低糖特浓即溶咖啡饮品 91g(13g7条)_盒
# 正在处理： 宝中宝保湿润肤霜250g_盒
# 正在处理： 怡宝Cestbon 饮用纯净水 555ml24瓶_箱
# 正在处理： 网红复古凯旋门猫眼墨镜女一副 黑框灰片款防晒椭圆形太阳眼镜
# 正在处理： 【USB转安卓】品胜 Micro接口安卓手机数据线 安卓充电线数据线 0.9米_条
# 正在处理： 华味亨 相思梅 160克_罐
# 正在处理： 家用酒精喷壶一个装颜色随机 消毒水清洁专用喷雾瓶气压式细雾浇花洒小喷水壶喷瓶~
# 正在处理： 【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子
# 正在处理： 【密封锁鲜】 白色家用饺子盒食品冰箱专用冷冻盒密封保鲜多层速冻馄饨水饺收纳盒 1_个
#   匹配结果：1
#   匹配结果：0
#   匹配结果：1
#   匹配结果：0
# 商品：【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 1\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   匹配结果：1
# 商品：网红复古凯旋门猫眼墨镜女一副 黑框灰片款防晒椭圆形太阳眼镜 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_inde...n    \n  \n    \n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
# 商品：华味亨 相思梅 160克_罐 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
# 商品：乐事 无限滋香烤肉味薯片 104g_罐 发生异常:
#   匹配结果：-1
# 商品：怡宝Cestbon 饮用纯净水 555ml24瓶_箱 发生异常:
#   匹配结果：-1
#   正在处理错误记录：475 - 喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套
#   正在处理错误记录：478 - 豹纹金钻辣妹穿戴甲30片_盒 高级感辣妹豹纹水钻法式手工穿戴甲
#   正在处理错误记录：479 - 假下眼睫毛纹身贴 女仿真下睫毛持久放水化妆一次性疤痕玩具防水睫毛纹身贴
#   正在处理错误记录：495 - 晨露 沁心薰衣草气雾清新剂 320ml_瓶
# 正在处理： 喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套
# 正在处理： 豹纹金钻辣妹穿戴甲30片_盒 高级感辣妹豹纹水钻法式手工穿戴甲
# 正在处理： 假下眼睫毛纹身贴 女仿真下睫毛持久放水化妆一次性疤痕玩具防水睫毛纹身贴
# 正在处理： 晨露 沁心薰衣草气雾清新剂 320ml_瓶
#   匹配结果：0
#   匹配结果：0
# 商品：喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 3\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   匹配结果：2
#
# ====== 第 2 次遍历，需重试记录：17 条 ======
#   正在处理错误记录：33 - 重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~
#   正在处理错误记录：67 - 卫龙亲嘴烧 经典香辣风味调味面制品 24g_袋
#   正在处理错误记录：143 - 汰渍Tide 柠檬清新型净白去渍洗衣粉 218g_袋
#   正在处理错误记录：197 - 晨露 淡雅茉莉清香盒 100g_盒
#   正在处理错误记录：210 - 金阳 圆形针线盒 约100g_盒
#   正在处理错误记录：233 - 娃哈哈AD钙奶儿童奶含乳饮料饮品童年哇哈哈 220gx4瓶／排
#   正在处理错误记录：242 - 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
#   正在处理错误记录：246 - 乌苏 11°P乌苏啤酒罐装 500ml_听
#   正在处理错误记录：250 - 李字 电热蚊香液 45ml2瓶_盒
#   正在处理错误记录：270 - 清扬去屑头皮护理洗发露养根韧发型175g_瓶
# 正在处理： 重型美工刀规格可选 工具架黑刃裁纸刀工业用多功能手工小刀片墙纸刀壁纸刀~
# 正在处理： 卫龙亲嘴烧 经典香辣风味调味面制品 24g_袋
# 正在处理： 汰渍Tide 柠檬清新型净白去渍洗衣粉 218g_袋
# 正在处理： 晨露 淡雅茉莉清香盒 100g_盒
# 正在处理： 金阳 圆形针线盒 约100g_盒
# 正在处理： 娃哈哈AD钙奶儿童奶含乳饮料饮品童年哇哈哈 220gx4瓶／排
# 正在处理： 冬季男士滑雪骑行手套1双 加厚保暖时尚滑雪摩托车电动车手套[不可触屏]
# 正在处理： 乌苏 11°P乌苏啤酒罐装 500ml_听
# 正在处理： 李字 电热蚊香液 45ml2瓶_盒
# 正在处理： 清扬去屑头皮护理洗发露养根韧发型175g_瓶
#   匹配结果：3
#   匹配结果：1
#   匹配结果：1
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
#   匹配结果：0
#   匹配结果：1
#   匹配结果：3
# 商品：晨露 淡雅茉莉清香盒 100g_盒 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#   正在处理错误记录：274 - 十月结晶 母乳储奶袋奶水保鲜储存冷冻存奶袋200ml母乳储存袋 30片装
#   正在处理错误记录：399 - 乐事 无限滋香烤肉味薯片 104g_罐
#   正在处理错误记录：420 - 怡宝Cestbon 饮用纯净水 555ml24瓶_箱
#   正在处理错误记录：422 - 网红复古凯旋门猫眼墨镜女一副 黑框灰片款防晒椭圆形太阳眼镜
#   正在处理错误记录：441 - 华味亨 相思梅 160克_罐
#   正在处理错误记录：448 - 【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子
#   正在处理错误记录：475 - 喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套
# 正在处理： 十月结晶 母乳储奶袋奶水保鲜储存冷冻存奶袋200ml母乳储存袋 30片装
# 正在处理： 乐事 无限滋香烤肉味薯片 104g_罐
# 正在处理： 怡宝Cestbon 饮用纯净水 555ml24瓶_箱
# 正在处理： 网红复古凯旋门猫眼墨镜女一副 黑框灰片款防晒椭圆形太阳眼镜
# 正在处理： 华味亨 相思梅 160克_罐
# 正在处理： 【送收纳袋】可折叠户外马扎凳米白 2328cm便携式钓鱼椅轻便折叠椅露营凳子
# 正在处理： 喇叭口小腿袜日系针织腿套52cm_双 jk堆堆袜软妹袜套千禧原宿显瘦袜套
#   匹配结果：0
#   匹配结果：1
#   匹配结果：1
#   匹配结果：1
#   匹配结果：1
#   匹配结果：1
# 商品：华味亨 相思梅 160克_罐 发生异常: 1 validation error for RankSelect
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='```json\n{\n  "rank_index": 0\n  }', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
#   匹配结果：-1
#
# ====== 第 3 次遍历，需重试记录：2 条 ======
#   正在处理错误记录：197 - 晨露 淡雅茉莉清香盒 100g_盒
#   正在处理错误记录：441 - 华味亨 相思梅 160克_罐
# 正在处理： 晨露 淡雅茉莉清香盒 100g_盒
# 正在处理： 华味亨 相思梅 160克_罐
#   匹配结果：0
# 商品：华味亨 相思梅 160克_罐 发生异常:
#   匹配结果：-1
#
# ====== 第 4 次遍历，需重试记录：1 条 ======
#   正在处理错误记录：441 - 华味亨 相思梅 160克_罐
# 正在处理： 华味亨 相思梅 160克_罐
#   匹配结果：2
#
# ====== 第 5 次遍历，需重试记录：0 条 ======
# 所有错误记录已处理完成！

# %%
# 提取相似商品列值为error的记录，相似商品列可能为None
error_rows = df[df['相似商品'].notnull() & df['相似商品'].str.contains('error')]
error_rows
# Out:
# Empty DataFrame
# Columns: [商品ID, 是否已打标, 商品名称, 规格, 条码, 折扣价, 原价, 活动, 销售, 店内一级分类, 店内二级分类, 图片, 库存, 描述, 属性, 好评率, 想买人数, 点赞数, 最小订购数, 标识, 三级分类json, tag, 美团一级分类, 美团二级分类, 美团三级分类, skuid, 相似商品1（ID-名称）, 相似商品2（ID-名称）, 相似商品3（ID-名称）, 相似商品]
# Index: []
#
# [0 rows x 30 columns]

# %%
# 导出excel
df.to_excel("../../output/补充Top3相似商品.xlsx", index=False)
