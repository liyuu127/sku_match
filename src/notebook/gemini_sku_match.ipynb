# %%
import pandas as pd
import jieba
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def clean_text(text):
    """
    清洗文本，去除特殊字符和多余空格
    """
    if not isinstance(text, str):
        return ""
    # 移除非中文字符、字母和数字
    text = re.sub(r'[^\u4e00-\u9fa5a-zA-Z0-9]', ' ', text)
    # 将多个空格合并为一个
    text = re.sub(r'\s+', ' ', text).strip()
    return text.lower()

# %%
text="元气森林 霸气汽水（冰红茶可乐味） 600ml_瓶"

# %%
clean_text("元气森林 霸气汽水（冰红茶可乐味） 600ml_瓶")
# Out:
# '元气森林 霸气汽水 冰红茶可乐味 600ml 瓶'

# %%
def chinese_tokenizer(text):
    """
    使用jieba进行中文分词
    """
    return " ".join(jieba.cut(text))

# %%
chinese_tokenizer(clean_text(text))
# Out:
# '元气 森林   霸气 汽水   冰红茶 可乐 味   600ml   瓶'

# %%
def find_top_n_similar_products(meituan_df, elme_df, n=3):
    """
    为meituan_sku中的每个商品匹配elme_sku中相似度前n的商品

    参数:
    - meituan_df: 美团商品DataFrame
    - elme_df: 饿了么商品DataFrame
    - n: 需要返回的相似商品数量

    返回:
    - 一个字典，键为美团商品ID，值为一个包含相似饿了么商品信息的列表
    """

    # 1. 数据预处理
    # 为了避免修改原始数据，我们创建副本
    meituan_df_copy = meituan_df.copy()
    elme_df_copy = elme_df.copy()

    # 统一列名，便于处理
    meituan_df_copy.rename(columns={'商品ID': 'id', '商品名称': 'name', '规格': 'spec', 'upc码': 'upc'}, inplace=True)
    elme_df_copy.rename(columns={'商品id': 'id', '商品名称': 'name', '规格': 'spec', '条码': 'upc'}, inplace=True)

    # 创建用于匹配的文本字段
    meituan_df_copy['match_text'] = meituan_df_copy['name'].astype(str) + " " + meituan_df_copy['spec'].astype(str)
    elme_df_copy['match_text'] = elme_df_copy['name'].astype(str) + " " + elme_df_copy['spec'].astype(str)

    # 清洗和分词
    meituan_df_copy['cleaned_text'] = meituan_df_copy['match_text'].apply(clean_text)
    elme_df_copy['cleaned_text'] = elme_df_copy['match_text'].apply(clean_text)

    meituan_df_copy['tokenized_text'] = meituan_df_copy['cleaned_text'].apply(chinese_tokenizer)
    elme_df_copy['tokenized_text'] = elme_df_copy['cleaned_text'].apply(chinese_tokenizer)

    # 2. TF-IDF向量化
    vectorizer = TfidfVectorizer()
    elme_tfidf_matrix = vectorizer.fit_transform(elme_df_copy['tokenized_text'])

    results = {}

    # 3. 遍历美团商品进行匹配
    for index, m_row in meituan_df_copy.iterrows():
        m_product_id = m_row['id']
        m_upc = m_row['upc']

        similarity_scores = {}

        # # 优先进行UPC码匹配
        # if pd.notna(m_upc) and m_upc != '':
        #     upc_matches = elme_df_copy[elme_df_copy['upc'] == m_upc]
        #     for _, e_row in upc_matches.iterrows():
        #         # UPC码匹配上的商品给予最高分1.0
        #         similarity_scores[e_row['id']] = 1.0

        # 进行文本相似度匹配
        m_tfidf_vector = vectorizer.transform([m_row['tokenized_text']])
        cosine_sims = cosine_similarity(m_tfidf_vector, elme_tfidf_matrix).flatten()

        # 将文本相似度分数存入字典
        for i, score in enumerate(cosine_sims):
            e_product_id = elme_df_copy.iloc[i]['id']
            # 如果该商品不是通过UPC码匹配上的，或者文本相似度更高，则更新分数
            if e_product_id not in similarity_scores or score > similarity_scores[e_product_id]:
                similarity_scores[e_product_id] = score

        # 排序并选出前N个
        sorted_scores = sorted(similarity_scores.items(), key=lambda item: item[1], reverse=True)
        top_n_matches = sorted_scores[:n]

        # 整理输出结果
        top_n_details = []
        for e_id, score in top_n_matches:
            matched_product = elme_df_copy[elme_df_copy['id'] == e_id].iloc[0]
            top_n_details.append({
                'matched_elme_id': matched_product['id'],
                'matched_elme_name': matched_product['name'],
                'matched_elme_spec': matched_product['spec'],
                'similarity_score': round(score, 4)
            })

        results[m_product_id] = {
            'meituan_name': m_row['name'],
            'meituan_spec': m_row['spec'],
            'top_matches': top_n_details
        }

    return results

# %%
# 加载csv文件
meituan_df = pd.read_csv('./meituan_sku_small.csv')
elme_df = pd.read_csv('./elme_sku_small.csv')

# %%
meituan_df.head()
# Out:
#           商品ID                                  商品名称               规格  \
# 0  20318304358  （规格自选强力布基胶带网格双面胶高粘度透明无痕地毯地垫沙发垫固定贴 一卷  5cm*10m#2cm*10m
# 1  20593235769                  海氏海诺 一次性医用外科口罩 10只_盒            10只/盒
# 2  20317711803                  爱斐堡 牛奶味生吐司 散装 约70g_袋           70g*1袋
# 3  20318114339            【1条】雀巢 脆脆鲨巧克力味威化饼干 零食营养能量棒               1根
# 4  20316956858                          天明 桉叶糖 22克_盒           22克*1盒
#
#            upc码    折扣价    原价        skuid
# 0  6.902051e+12  12.45  15.0  35112245909
# 1  6.925924e+12  12.96  15.8  35816960188
# 2  6.971985e+12   4.58   5.2  35111173396
# 3  6.901884e+12   3.76   2.0  35113206574
# 4  6.901311e+12   2.64   3.0  35110532938

# %%
elme_df.head()
# Out:
#            商品id                           商品名称  规格             条码   折扣价   原价  \
# 0  950657120093  汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶 NaN  6925303770563  3.49  8.3
# 1  950103769331       康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶 NaN  6920152424285  4.90  6.5
# 2  949473714726              上好佳 鲜虾片膨化食品 80克/袋 NaN  6926265313386  5.20  8.0
# 3  949474714550             百威 9.7°P啤酒 500ml/听 NaN  6948960100078  0.01  9.5
# 4  949480010428              统一茄皇 茄皇牛肉面 128g/桶 NaN  6925303796426  5.50  7.5
#
#           skuid
# 0  950657120093
# 1  950103769331
# 2  949473714726
# 3  949474714550
# 4  949480010428

# %%
products = find_top_n_similar_products(meituan_df, elme_df)
products
# Out:
# {20318304358: {'meituan_name': '（规格自选强力布基胶带网格双面胶高粘度透明无痕地毯地垫沙发垫固定贴 一卷',
#   'meituan_spec': '5cm*10m#2cm*10m',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20593235769: {'meituan_name': '海氏海诺 一次性医用外科口罩 10只_盒',
#   'meituan_spec': '10只/盒',
#   'top_matches': [{'matched_elme_id': 949021019485,
#     'matched_elme_name': '心相印 杀菌卫生湿巾 10片/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3454},
#    {'matched_elme_id': 950129193493,
#     'matched_elme_name': '青岛啤酒 10°P经典啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3406},
#    {'matched_elme_id': 949023655620,
#     'matched_elme_name': '淘淘氧棉天山白 240mm轻盈无边纯棉日用卫生巾 10片/包',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2407}]},
#  20317711803: {'meituan_name': '爱斐堡 牛奶味生吐司 散装 约70g_袋',
#   'meituan_spec': '70g*1袋',
#   'top_matches': [{'matched_elme_id': 949473410578,
#     'matched_elme_name': '老李 五香干 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4181},
#    {'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3177},
#    {'matched_elme_id': 949476034503,
#     'matched_elme_name': '浪味仙 蔬菜口味创意花式薯卷 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.268}]},
#  20318114339: {'meituan_name': '【1条】雀巢 脆脆鲨巧克力味威化饼干 零食营养能量棒',
#   'meituan_spec': '1根',
#   'top_matches': [{'matched_elme_id': 949475162600,
#     'matched_elme_name': 'Richeese 丽芝士 纳宝帝奶酪味威化饼干 56g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3809},
#    {'matched_elme_id': 949011555171,
#     'matched_elme_name': '娃哈哈营养快线 水果酸奶饮品 500g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2068},
#    {'matched_elme_id': 949015511254,
#     'matched_elme_name': '太平 低糖奶盐味梳打饼干 100g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1936}]},
#  20316956858: {'meituan_name': '天明 桉叶糖 22克_盒',
#   'meituan_spec': '22克*1盒',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20319809089: {'meituan_name': '洽洽 香瓜子 洽洽坚果炒货 110g／包',
#   'meituan_spec': '110g/包',
#   'top_matches': [{'matched_elme_id': 949019347220,
#     'matched_elme_name': '洽洽 香瓜子 160g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.614},
#    {'matched_elme_id': 949028799678,
#     'matched_elme_name': '洽洽香瓜子葵瓜子原味恰恰原香瓜子前台接待坚果炒货休闲KTV零食 260g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5779},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20470087532: {'meituan_name': '秀峰香 肉松沙拉三明治面包 65g_袋',
#   'meituan_spec': '65g*1袋',
#   'top_matches': [{'matched_elme_id': 950676368263,
#     'matched_elme_name': '南街村 北京麻辣方便面 65g／袋 儿时的味道经典麻辣味',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3205},
#    {'matched_elme_id': 949015899222,
#     'matched_elme_name': '达利园 香奶味法式软面包 360g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2057},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20649168306: {'meituan_name': "【山姆同款】Member's Mark 榛子味威化饼干_45g袋",
#   'meituan_spec': nan,
#   'top_matches': [{'matched_elme_id': 949475162600,
#     'matched_elme_name': 'Richeese 丽芝士 纳宝帝奶酪味威化饼干 56g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4227},
#    {'matched_elme_id': 949015511254,
#     'matched_elme_name': '太平 低糖奶盐味梳打饼干 100g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2205},
#    {'matched_elme_id': 949473118005,
#     'matched_elme_name': '好丽友好有趣 韩国泡菜味好友趣切片型马铃薯片 45g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2184}]},
#  20319136979: {'meituan_name': '【新鲜时令】进口新鲜水果越南香蕉500g约3-5根_份',
#   'meituan_spec': '500g*1份',
#   'top_matches': [{'matched_elme_id': 949011555171,
#     'matched_elme_name': '娃哈哈营养快线 水果酸奶饮品 500g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5114},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20318183497: {'meituan_name': '达利园 香奶味软面包  200g／袋 面包就要达利园',
#   'meituan_spec': '200g*1袋',
#   'top_matches': [{'matched_elme_id': 949015899222,
#     'matched_elme_name': '达利园 香奶味法式软面包 360g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.7449},
#    {'matched_elme_id': 949028739570,
#     'matched_elme_name': '达利园 桂圆莲子八宝粥 360g/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2678},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20318504675: {'meituan_name': '脆司令 奥尔良鸡翅味香脆面干脆面 53g／袋',
#   'meituan_spec': '53g*1袋',
#   'top_matches': [{'matched_elme_id': 955473677412,
#     'matched_elme_name': '【鲨鱼菲特】轻食 奥尔良味 低脂嫩烤鸡胸肉 60g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2309},
#    {'matched_elme_id': 949018491523,
#     'matched_elme_name': '乐事 香脆烤鸡翅味大波浪薯片 70克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2244},
#    {'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2192}]},
#  20318026323: {'meituan_name': '小浣熊 滋滋烤肉味干脆面 有肉任性35g／袋 初心不改美味依旧（包装随机发货）',
#   'meituan_spec': '35克',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.6351},
#    {'matched_elme_id': 950100413689,
#     'matched_elme_name': '劲牌 35度中国劲酒 125ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1796},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1508}]},
#  20319641691: {'meituan_name': '马来西亚进口大马碧富咸柠檬薄荷糖清凉青柠味清新himalaya润喉糖15克_袋',
#   'meituan_spec': nan,
#   'top_matches': [{'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2257},
#    {'matched_elme_id': 950124625023,
#     'matched_elme_name': '佳洁士 盐白牙膏自然洁白冰感清新 90g／支',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1689},
#    {'matched_elme_id': 949475726937,
#     'matched_elme_name': '雪碧Sprite 清爽柠檬味雪碧汽水 2l/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1601}]},
#  20319728224: {'meituan_name': '劲仔 香辣小鱼 12g_袋',
#   'meituan_spec': '12g*1袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20320245924: {'meituan_name': '好丽友派 巧克力味涂饰蛋类芯饼 68g／盒',
#   'meituan_spec': '68g*1盒',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20319567245: {'meituan_name': '金厨娘 美味鸭掌 28g_袋',
#   'meituan_spec': '28克/袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.358},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20318976028: {'meituan_name': '45米大号封箱胶带快递打包透明胶条加厚加宽包装胶布胶纸封箱带 _个',
#   'meituan_spec': nan,
#   'top_matches': [{'matched_elme_id': 950101321402,
#     'matched_elme_name': '一次性浴巾旅行单独包装一次毛巾加厚加大不掉絮浴巾民宿酒店（60x120cm）',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2687},
#    {'matched_elme_id': 950103969919,
#     'matched_elme_name': '郎 45度小郎酒浓酱兼香型白酒 100ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2575},
#    {'matched_elme_id': 950119273131,
#     'matched_elme_name': '超凡 打火机防爆加厚版打火机 1个／件款式随机',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1644}]},
#  20316758375: {'meituan_name': '脆司令 香葱蛋卷味香脆面 53g_袋',
#   'meituan_spec': '53克/袋',
#   'top_matches': [{'matched_elme_id': 949018491523,
#     'matched_elme_name': '乐事 香脆烤鸡翅味大波浪薯片 70克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3886},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20511433517: {'meituan_name': '迪味臻五香卤蛋 30g_袋',
#   'meituan_spec': '30g*1袋',
#   'top_matches': [{'matched_elme_id': 949479934319,
#     'matched_elme_name': '迪味臻五香卤蛋 30g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9389},
#    {'matched_elme_id': 949473410578,
#     'matched_elme_name': '老李 五香干 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1792},
#    {'matched_elme_id': 949021931793,
#     'matched_elme_name': '合味道 五香牛肉风味方便面 77g/杯',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1279}]},
#  20617709736: {'meituan_name': '黄瓜约500g_份',
#   'meituan_spec': '500g*1份',
#   'top_matches': [{'matched_elme_id': 949011555171,
#     'matched_elme_name': '娃哈哈营养快线 水果酸奶饮品 500g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3409},
#    {'matched_elme_id': 950690324031,
#     'matched_elme_name': '【口感松脆】乐事 薯片原味黄瓜多口味膨化土豆片休闲零食 口味随机 40g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1321},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20320160947: {'meituan_name': '海氏海诺 透明防水创可贴6片／盒 可用于创面保护防感染',
#   'meituan_spec': '6片*1盒',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317632702: {'meituan_name': 'GEMEZ 烤鸡风味小鸡干脆面 30g_袋',
#   'meituan_spec': '30克/袋',
#   'top_matches': [{'matched_elme_id': 949479934319,
#     'matched_elme_name': '迪味臻五香卤蛋 30g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2382},
#    {'matched_elme_id': 949018491523,
#     'matched_elme_name': '乐事 香脆烤鸡翅味大波浪薯片 70克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.18},
#    {'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1758}]},
#  20318029263: {'meituan_name': '小米 指甲剪米家防飞溅家用指甲刀女修指甲不锈钢指甲刀／把',
#   'meituan_spec': '1个*1份',
#   'top_matches': [{'matched_elme_id': 950450037712,
#     'matched_elme_name': '塑料脸盆加厚婴儿脸盆家用小号面盆/个',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3198},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317942303: {'meituan_name': '魔法士 巴西烤肉油炸方便面 35g_袋',
#   'meituan_spec': '35g*1袋',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5362},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3424},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1723}]},
#  20318061125: {'meituan_name': '【脆司令】黑椒牛排味干脆面 53g_袋',
#   'meituan_spec': '53克/袋',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2684},
#    {'matched_elme_id': 956054440170,
#     'matched_elme_name': '鲨鱼菲特   黑椒味鸡胸肉即食健身代餐0减低脂高蛋白轻食主食鸡肉零食品60g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1942},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20423558709: {'meituan_name': '米多奇 烤馍片非油炸烘烤糕点小零食（口味随机发）50g_袋',
#   'meituan_spec': '50g*1袋',
#   'top_matches': [{'matched_elme_id': 949022291561,
#     'matched_elme_name': '米多奇 烤馍片非油炸烘烤糕点小零食（口味随机发）50g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9516},
#    {'matched_elme_id': 950111149923,
#     'matched_elme_name': '爱尚咪咪 虾味油炸糕点虾条 18克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.215},
#    {'matched_elme_id': 949472446011,
#     'matched_elme_name': '上好佳Oishi 无反式脂肪海苔味日式鱼果膨化食品 50g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2072}]},
#  20319619619: {'meituan_name': '小浣熊 奥尔良烤翅味35g／袋 干脆面儿时的回忆（新老包装随机）',
#   'meituan_spec': '35g*1袋（包装随机）',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.445},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.204},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1783}]},
#  20318107574: {'meituan_name': '中街 糯米糍香草口味雪糕 35g_袋',
#   'meituan_spec': '35g*1袋',
#   'top_matches': [{'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9486},
#    {'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2807},
#    {'matched_elme_id': 950106965145,
#     'matched_elme_name': '屈臣氏watsons 香草味苏打汽水 330毫升/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1222}]},
#  20319926121: {'meituan_name': '劲仔 酱汁味小鱼干 深海小鱼休闲零食 12g／袋',
#   'meituan_spec': '12g*1袋',
#   'top_matches': [{'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5174},
#    {'matched_elme_id': 950690324031,
#     'matched_elme_name': '【口感松脆】乐事 薯片原味黄瓜多口味膨化土豆片休闲零食 口味随机 40g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.336},
#    {'matched_elme_id': 949028799678,
#     'matched_elme_name': '洽洽香瓜子葵瓜子原味恰恰原香瓜子前台接待坚果炒货休闲KTV零食 260g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2638}]},
#  20318543394: {'meituan_name': '卫龙 魔芋爽香辣素毛肚 80 克_袋',
#   'meituan_spec': '80克*1袋',
#   'top_matches': [{'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4503},
#    {'matched_elme_id': 949013951817,
#     'matched_elme_name': '卫龙亲嘴烧 经典香辣味调味面制品 20g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1917},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317874640: {'meituan_name': '乐事 经典原味薯片够薄够脆口味纯正 70g／袋',
#   'meituan_spec': '70g*1袋',
#   'top_matches': [{'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4197},
#    {'matched_elme_id': 949473410578,
#     'matched_elme_name': '老李 五香干 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3682},
#    {'matched_elme_id': 950690324031,
#     'matched_elme_name': '【口感松脆】乐事 薯片原味黄瓜多口味膨化土豆片休闲零食 口味随机 40g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3647}]},
#  20330837351: {'meituan_name': '仅限一份【惊喜盲盒】饮料？可乐？各种零食（惊喜不断）',
#   'meituan_spec': '1个*1份',
#   'top_matches': [{'matched_elme_id': 949028939596,
#     'matched_elme_name': '【惊喜盲盒】饮料？可乐？各种零食（惊喜不断）仅限一份（多拍无效）',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9623},
#    {'matched_elme_id': 949014347911,
#     'matched_elme_name': '王老吉 凉茶植物饮料 1.5升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0898},
#    {'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.077}]},
#  20320284623: {'meituan_name': '狗牙儿 比萨卷烧烤味儿时怀旧回忆小零食 20g／袋',
#   'meituan_spec': '20g*1袋',
#   'top_matches': [{'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4186},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3726},
#    {'matched_elme_id': 949013951817,
#     'matched_elme_name': '卫龙亲嘴烧 经典香辣味调味面制品 20g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2772}]},
#  20319449643: {'meituan_name': '精选新鲜越南香蕉 1根约100g',
#   'meituan_spec': '100g*1份',
#   'top_matches': [{'matched_elme_id': 949015511254,
#     'matched_elme_name': '太平 低糖奶盐味梳打饼干 100g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3889},
#    {'matched_elme_id': 949026491329,
#     'matched_elme_name': '李子柒 柳州螺狮粉 335g(米粉包100g调味包235g)/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3336},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20318064463: {'meituan_name': '【小包】禛香肥牛牛肉味素食风味就选 18g_袋',
#   'meituan_spec': '18g*1袋',
#   'top_matches': [{'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3878},
#    {'matched_elme_id': 949021931793,
#     'matched_elme_name': '合味道 五香牛肉风味方便面 77g/杯',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3044},
#    {'matched_elme_id': 949032555760,
#     'matched_elme_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.204}]},
#  20320044975: {'meituan_name': '加多宝 凉茶植物饮料 310ml／罐',
#   'meituan_spec': '310ml*1罐',
#   'top_matches': [{'matched_elme_id': 949475290173,
#     'matched_elme_name': '加多宝 凉茶 310ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.8313},
#    {'matched_elme_id': 949501242915,
#     'matched_elme_name': '王老吉 植物凉茶清凉降火本草植物配制 310ml／罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5151},
#    {'matched_elme_id': 949014347911,
#     'matched_elme_name': '王老吉 凉茶植物饮料 1.5升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4776}]},
#  20319054021: {'meituan_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#   'meituan_spec': '18g*1袋',
#   'top_matches': [{'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9607},
#    {'matched_elme_id': 950676368263,
#     'matched_elme_name': '南街村 北京麻辣方便面 65g／袋 儿时的味道经典麻辣味',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1669},
#    {'matched_elme_id': 949032555760,
#     'matched_elme_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1551}]},
#  20317232851: {'meituan_name': '简禾 酒精湿巾湿纸巾大包一次性消毒纸巾家用厨房卫生纸 80片_包',
#   'meituan_spec': '80片/包',
#   'top_matches': [{'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.373},
#    {'matched_elme_id': 949021019485,
#     'matched_elme_name': '心相印 杀菌卫生湿巾 10片/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1843},
#    {'matched_elme_id': 950450037712,
#     'matched_elme_name': '塑料脸盆加厚婴儿脸盆家用小号面盆/个',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1267}]},
#  20318743694: {'meituan_name': '娃哈哈 桂圆八宝八宝粥 360g_罐',
#   'meituan_spec': '360g*1罐',
#   'top_matches': [{'matched_elme_id': 949028739570,
#     'matched_elme_name': '达利园 桂圆莲子八宝粥 360g/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.6716},
#    {'matched_elme_id': 949015899222,
#     'matched_elme_name': '达利园 香奶味法式软面包 360g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.307},
#    {'matched_elme_id': 949011555171,
#     'matched_elme_name': '娃哈哈营养快线 水果酸奶饮品 500g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.151}]},
#  20611879606: {'meituan_name': '伊利冰工厂 炫菠萝雪泥 70g_袋',
#   'meituan_spec': '70g*1袋',
#   'top_matches': [{'matched_elme_id': 949473410578,
#     'matched_elme_name': '老李 五香干 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.468},
#    {'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3556},
#    {'matched_elme_id': 949497690817,
#     'matched_elme_name': '伊利 纯牛奶  伊利品质值得信赖 250ml／盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3346}]},
#  20320003977: {'meituan_name': '旺仔 牛奶 145ml_罐',
#   'meituan_spec': '145ml*1罐',
#   'top_matches': [{'matched_elme_id': 949010755211,
#     'matched_elme_name': '李子园 甜牛奶饮品 450ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3664},
#    {'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3217},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20319379653: {'meituan_name': '步步升 南京板鸭 儿时回忆办公休闲小零嘴 20g／袋',
#   'meituan_spec': '20克/袋',
#   'top_matches': [{'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3418},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3108},
#    {'matched_elme_id': 949013951817,
#     'matched_elme_name': '卫龙亲嘴烧 经典香辣味调味面制品 20g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1604}]},
#  20442838920: {'meituan_name': '好丽友好有趣 韩国泡菜味好友趣切片型马铃薯片 45g_袋',
#   'meituan_spec': '45g*1袋',
#   'top_matches': [{'matched_elme_id': 949473118005,
#     'matched_elme_name': '好丽友好有趣 韩国泡菜味好友趣切片型马铃薯片 45g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9564},
#    {'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1225},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317713915: {'meituan_name': '小浣熊 销魂香辣蟹味油炸方便面 35g_袋',
#   'meituan_spec': '35g*1袋',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.6456},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3113},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1567}]},
#  20319294692: {'meituan_name': '上海特产老城隍庙奶油五香豆200克蚕豆休闲零食_袋',
#   'meituan_spec': '200克',
#   'top_matches': [{'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5174},
#    {'matched_elme_id': 950690324031,
#     'matched_elme_name': '【口感松脆】乐事 薯片原味黄瓜多口味膨化土豆片休闲零食 口味随机 40g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.336},
#    {'matched_elme_id': 949028799678,
#     'matched_elme_name': '洽洽香瓜子葵瓜子原味恰恰原香瓜子前台接待坚果炒货休闲KTV零食 260g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2638}]},
#  20319293916: {'meituan_name': '爱尚咪咪 虾味油炸糕点虾条 18克_袋',
#   'meituan_spec': '18克*1袋',
#   'top_matches': [{'matched_elme_id': 950111149923,
#     'matched_elme_name': '爱尚咪咪 虾味油炸糕点虾条 18克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9517},
#    {'matched_elme_id': 949022291561,
#     'matched_elme_name': '米多奇 烤馍片非油炸烘烤糕点小零食（口味随机发）50g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2143},
#    {'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0905}]},
#  20317987927: {'meituan_name': '旺旺 大米饼 135g_袋',
#   'meituan_spec': '135g*1袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20318981267: {'meituan_name': '甘师傅 一根葱葱香味一根葱非油炸膨化食品 13g／袋怀旧小食品',
#   'meituan_spec': '13g*1袋',
#   'top_matches': [{'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2213},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1903},
#    {'matched_elme_id': 949022291561,
#     'matched_elme_name': '米多奇 烤馍片非油炸烘烤糕点小零食（口味随机发）50g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1662}]},
#  20592674507: {'meituan_name': '双汇 王中王火腿肠 30g_根',
#   'meituan_spec': '30g*1根',
#   'top_matches': [{'matched_elme_id': 949479934319,
#     'matched_elme_name': '迪味臻五香卤蛋 30g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4601},
#    {'matched_elme_id': 949031079366,
#     'matched_elme_name': '双汇 台式烤香肠 38g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2225},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317744278: {'meituan_name': '缺牙齿 香辣味素牛肚 16g_袋',
#   'meituan_spec': '16g*1袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20902350634: {'meituan_name': '冈本okamoto 001超润滑聚氨酯避孕套 3片_盒',
#   'meituan_spec': '3片*1盒',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20795811956: {'meituan_name': '七鲜巴马弱碱性天然泉水 380ml_瓶',
#   'meituan_spec': '380ml/瓶',
#   'top_matches': [{'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4339},
#    {'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2079},
#    {'matched_elme_id': 950121025012,
#     'matched_elme_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1459}]},
#  20795811947: {'meituan_name': '七鲜巴马弱碱性天然泉水 500ml_瓶',
#   'meituan_spec': '500ml/瓶',
#   'top_matches': [{'matched_elme_id': 949474714550,
#     'matched_elme_name': '百威 9.7°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3882},
#    {'matched_elme_id': 949011367952,
#     'matched_elme_name': '百威Budweiser 9.7°P啤酒 500ml*3罐/盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3062},
#    {'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2967}]},
#  20317356107: {'meituan_name': '【规格可选】编织袋打包袋蛇皮袋搬家快递打包装修垃圾沙土袋1个',
#   'meituan_spec': '100*150cm',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  21722804533: {'meituan_name': '迪味臻小鱼口味随机12g1袋',
#   'meituan_spec': nan,
#   'top_matches': [{'matched_elme_id': 949479934319,
#     'matched_elme_name': '迪味臻五香卤蛋 30g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4112},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3039},
#    {'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2656}]},
#  20317552424: {'meituan_name': '农夫山泉 天然饮用水 5L／桶',
#   'meituan_spec': '5l*1桶',
#   'top_matches': [{'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9374},
#    {'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2851},
#    {'matched_elme_id': 950121025012,
#     'matched_elme_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1274}]},
#  21152166207: {'meituan_name': '形象美 玻尿酸水润精华面膜 1片',
#   'meituan_spec': '25g*1片',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20779076810: {'meituan_name': '【颜色随机】大号塑料圆形垃圾桶办公室卫生间厕所家用厨房圆形纸篓种蒜筐_个',
#   'meituan_spec': nan,
#   'top_matches': [{'matched_elme_id': 950450037712,
#     'matched_elme_name': '塑料脸盆加厚婴儿脸盆家用小号面盆/个',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3568},
#    {'matched_elme_id': 950121025012,
#     'matched_elme_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2169},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.108}]},
#  20319889182: {'meituan_name': '红牛 维生素功能饮料罐装 250ml／罐',
#   'meituan_spec': '250ml*1罐',
#   'top_matches': [{'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3206},
#    {'matched_elme_id': 949497690817,
#     'matched_elme_name': '伊利 纯牛奶  伊利品质值得信赖 250ml／盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2832},
#    {'matched_elme_id': 949014347911,
#     'matched_elme_name': '王老吉 凉茶植物饮料 1.5升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1273}]},
#  20612982160: {'meituan_name': '蒙牛绿色心情 绿莎莎雪糕 70g_支',
#   'meituan_spec': '70g*1支',
#   'top_matches': [{'matched_elme_id': 949473410578,
#     'matched_elme_name': '老李 五香干 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.468},
#    {'matched_elme_id': 949021867021,
#     'matched_elme_name': '乐事 青柠味原切马铃薯片 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3556},
#    {'matched_elme_id': 949476034503,
#     'matched_elme_name': '浪味仙 蔬菜口味创意花式薯卷 70g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3}]},
#  20318972257: {'meituan_name': '清风 原木卷纸 1卷',
#   'meituan_spec': '1卷*1袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20319686677: {'meituan_name': '旺旺 碎冰冰 78g／支【口味随机】',
#   'meituan_spec': '78g*1支',
#   'top_matches': [{'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.46},
#    {'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.402},
#    {'matched_elme_id': 950656340154,
#     'matched_elme_name': '【口味随机】东方树叶 0卡茶饮料 500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4007}]},
#  20594652316: {'meituan_name': '康师傅 低糖绿茶饮料 1l_瓶【红绿随机】',
#   'meituan_spec': '1l*1瓶',
#   'top_matches': [{'matched_elme_id': 950094933365,
#     'matched_elme_name': '康师傅 低糖绿茶饮料 1l/瓶【红绿随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9467},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2048},
#    {'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1409}]},
#  20595171196: {'meituan_name': '康师傅红茶茶饮料 500毫升_瓶【口味随机】',
#   'meituan_spec': '500毫升*1瓶',
#   'top_matches': [{'matched_elme_id': 949475110648,
#     'matched_elme_name': '【口味随机】三得利SUNTORY 乌龙茶饮料 500毫升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5266},
#    {'matched_elme_id': 950656340154,
#     'matched_elme_name': '【口味随机】东方树叶 0卡茶饮料 500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2548},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2462}]},
#  20319618647: {'meituan_name': 'if 椰汁水国进口纯椰子水果汁无添加  350ml／瓶',
#   'meituan_spec': '350毫升',
#   'top_matches': [{'matched_elme_id': 949024023781,
#     'matched_elme_name': '真露JINRO 13度桃子味利口酒 360毫升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3525},
#    {'matched_elme_id': 949475110648,
#     'matched_elme_name': '【口味随机】三得利SUNTORY 乌龙茶饮料 500毫升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3522},
#    {'matched_elme_id': 950106965145,
#     'matched_elme_name': '屈臣氏watsons 香草味苏打汽水 330毫升/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3427}]},
#  20317676593: {'meituan_name': '农夫山泉茶π瓶茶派蜜桃乌龙柠檬红茶青提茶兀【口味随机】500ml_瓶',
#   'meituan_spec': '500毫升/瓶',
#   'top_matches': [{'matched_elme_id': 949032295071,
#     'matched_elme_name': '农夫山泉茶π瓶茶派蜜桃乌龙柠檬红茶青提茶兀【口味随机】500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.8861},
#    {'matched_elme_id': 949475110648,
#     'matched_elme_name': '【口味随机】三得利SUNTORY 乌龙茶饮料 500毫升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3409},
#    {'matched_elme_id': 950656340154,
#     'matched_elme_name': '【口味随机】东方树叶 0卡茶饮料 500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1788}]},
#  20319807738: {'meituan_name': '农夫山泉 天然饮用水 1.5L／瓶 天然水大瓶装',
#   'meituan_spec': '1.5l*1瓶',
#   'top_matches': [{'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.8712},
#    {'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4411},
#    {'matched_elme_id': 950121025012,
#     'matched_elme_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1184}]},
#  20317945136: {'meituan_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#   'meituan_spec': '348ml/瓶',
#   'top_matches': [{'matched_elme_id': 950121025012,
#     'matched_elme_name': '百岁山 天然矿泉水 办公室会议小瓶装水 348ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9528},
#    {'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1458},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20319298638: {'meituan_name': '【国货之光】娃哈哈 饮用纯净水 596ml／瓶',
#   'meituan_spec': '596ml*1瓶',
#   'top_matches': [{'matched_elme_id': 949029551023,
#     'matched_elme_name': '农夫山泉 饮用纯净水 550ml*12瓶（整件散装随机）',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4223},
#    {'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2384},
#    {'matched_elme_id': 949011555171,
#     'matched_elme_name': '娃哈哈营养快线 水果酸奶饮品 500g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2261}]},
#  20317391196: {'meituan_name': '哇哈哈 ad钙奶 220g_瓶',
#   'meituan_spec': '220g*1瓶',
#   'top_matches': [{'matched_elme_id': 949486646497,
#     'matched_elme_name': '哇哈哈 ad钙奶 220g/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9401},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317993427: {'meituan_name': '怡宝 饮用纯净水 饮用水  555ml／瓶',
#   'meituan_spec': '555ml*1瓶',
#   'top_matches': [{'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4907},
#    {'matched_elme_id': 949029551023,
#     'matched_elme_name': '农夫山泉 饮用纯净水 550ml*12瓶（整件散装随机）',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4346},
#    {'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2792}]},
#  20320121272: {'meituan_name': '农夫山泉 天然饮用水 天然饮用水 550ml／瓶',
#   'meituan_spec': '550ml*1瓶',
#   'top_matches': [{'matched_elme_id': 949492998044,
#     'matched_elme_name': '农夫山泉 天然饮用水 5L／桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.6486},
#    {'matched_elme_id': 950127145958,
#     'matched_elme_name': '农夫山泉 饮用水 饮用天然水 380ml／瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3318},
#    {'matched_elme_id': 949029551023,
#     'matched_elme_name': '农夫山泉 饮用纯净水 550ml*12瓶（整件散装随机）',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3048}]},
#  20318784104: {'meituan_name': '王老吉 植物凉茶清凉降火本草植物配制 310ml／罐',
#   'meituan_spec': '310ml*1罐',
#   'top_matches': [{'matched_elme_id': 949501242915,
#     'matched_elme_name': '王老吉 植物凉茶清凉降火本草植物配制 310ml／罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9662},
#    {'matched_elme_id': 949014347911,
#     'matched_elme_name': '王老吉 凉茶植物饮料 1.5升/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5389},
#    {'matched_elme_id': 949475290173,
#     'matched_elme_name': '加多宝 凉茶 310ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4263}]},
#  20593266460: {'meituan_name': '元气森林 0糖0脂0卡气元气森林气泡水 480ml_瓶【口味随机】',
#   'meituan_spec': '480ml*1瓶',
#   'top_matches': [{'matched_elme_id': 950102261140,
#     'matched_elme_name': '元气森林 0糖0脂0卡气元气森林气泡水 480ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9666},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0973},
#    {'matched_elme_id': 950658656253,
#     'matched_elme_name': '脉动 维生素饮料 600ml/瓶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.085}]},
#  20319326172: {'meituan_name': '百威 9.7°P啤酒 500ml_听',
#   'meituan_spec': '500ml*1听',
#   'top_matches': [{'matched_elme_id': 949474714550,
#     'matched_elme_name': '百威 9.7°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9336},
#    {'matched_elme_id': 949011367952,
#     'matched_elme_name': '百威Budweiser 9.7°P啤酒 500ml*3罐/盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.7363},
#    {'matched_elme_id': 950129193493,
#     'matched_elme_name': '青岛啤酒 10°P经典啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4786}]},
#  20317718385: {'meituan_name': '雪碧 清爽柠檬味汽水 500ml／瓶 透心凉夏季解渴饮品',
#   'meituan_spec': '500ml*1瓶',
#   'top_matches': [{'matched_elme_id': 949475726937,
#     'matched_elme_name': '雪碧Sprite 清爽柠檬味雪碧汽水 2l/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5414},
#    {'matched_elme_id': 949494350862,
#     'matched_elme_name': '雪花清爽 清爽8°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4594},
#    {'matched_elme_id': 949032295071,
#     'matched_elme_name': '农夫山泉茶π瓶茶派蜜桃乌龙柠檬红茶青提茶兀【口味随机】500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2659}]},
#  20317827561: {'meituan_name': '雪花清爽 清爽8°P啤酒 500ml_听',
#   'meituan_spec': '500ml*1听',
#   'top_matches': [{'matched_elme_id': 949494350862,
#     'matched_elme_name': '雪花清爽 清爽8°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9672},
#    {'matched_elme_id': 949474714550,
#     'matched_elme_name': '百威 9.7°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3905},
#    {'matched_elme_id': 950129193493,
#     'matched_elme_name': '青岛啤酒 10°P经典啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3184}]},
#  20317119570: {'meituan_name': '可口可乐 零度无糖汽水 0糖0脂肪健身必备 330ml／罐',
#   'meituan_spec': '330ml*1罐',
#   'top_matches': [{'matched_elme_id': 949012951044,
#     'matched_elme_name': '【随机品牌】可口可乐雪碧美年达芬达多种口味汽水 330ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4238},
#    {'matched_elme_id': 949016895490,
#     'matched_elme_name': '北冰洋 橙汁汽水 330ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.417},
#    {'matched_elme_id': 949476290380,
#     'matched_elme_name': '锐澳 微醺葡萄白兰地味鸡尾酒 330ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2433}]},
#  20318264219: {'meituan_name': '【随机品牌】可口可乐雪碧美年达芬达多种口味汽水 330ml_罐',
#   'meituan_spec': '330ml*1罐',
#   'top_matches': [{'matched_elme_id': 949012951044,
#     'matched_elme_name': '【随机品牌】可口可乐雪碧美年达芬达多种口味汽水 330ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9671},
#    {'matched_elme_id': 949016895490,
#     'matched_elme_name': '北冰洋 橙汁汽水 330ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3368},
#    {'matched_elme_id': 949475726937,
#     'matched_elme_name': '雪碧Sprite 清爽柠檬味雪碧汽水 2l/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1975}]},
#  20319447634: {'meituan_name': '【口味随机】东方树叶 0卡茶饮料 500ml_瓶',
#   'meituan_spec': '500ml*1瓶',
#   'top_matches': [{'matched_elme_id': 950656340154,
#     'matched_elme_name': '【口味随机】东方树叶 0卡茶饮料 500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9611},
#    {'matched_elme_id': 949474714550,
#     'matched_elme_name': '百威 9.7°P啤酒 500ml/听',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2628},
#    {'matched_elme_id': 949032295071,
#     'matched_elme_name': '农夫山泉茶π瓶茶派蜜桃乌龙柠檬红茶青提茶兀【口味随机】500ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2434}]},
#  20319487391: {'meituan_name': '雪菲力 荔枝味复合果汁饮料 250ml_盒',
#   'meituan_spec': '250ml*1盒',
#   'top_matches': [{'matched_elme_id': 949497690817,
#     'matched_elme_name': '伊利 纯牛奶  伊利品质值得信赖 250ml／盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2638},
#    {'matched_elme_id': 949013551412,
#     'matched_elme_name': '江小白 15度果汁含量＞30%果立方白葡萄味果汁酒 168ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2424},
#    {'matched_elme_id': 949015455720,
#     'matched_elme_name': '锐澳RIO 8度强爽荔枝伏特加鸡尾酒 500ml/罐',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1462}]},
#  20319528527: {'meituan_name': '伊利 草莓味优酸乳 250ml／盒 酸酸甜甜就是我',
#   'meituan_spec': '250ml*1盒',
#   'top_matches': [{'matched_elme_id': 949497690817,
#     'matched_elme_name': '伊利 纯牛奶  伊利品质值得信赖 250ml／盒',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.5431},
#    {'matched_elme_id': 950692372216,
#     'matched_elme_name': '真露JINRO 13度草莓味利口酒 360ml/瓶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1818},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317996612: {'meituan_name': '鲲乐 素牛味棒辣条小零食回忆辣条怀旧零食 15g／袋',
#   'meituan_spec': '15克/袋',
#   'top_matches': [{'matched_elme_id': 949032555760,
#     'matched_elme_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3917},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3635},
#    {'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1665}]},
#  20318112912: {'meituan_name': '味芝元 香辣鱼排 26g／袋',
#   'meituan_spec': '26g*1袋',
#   'top_matches': [{'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317836095: {'meituan_name': '南街村 北京麻辣方便面 65g／袋 儿时的味道经典麻辣味',
#   'meituan_spec': '65g*1袋',
#   'top_matches': [{'matched_elme_id': 950676368263,
#     'matched_elme_name': '南街村 北京麻辣方便面 65g／袋 儿时的味道经典麻辣味',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9561},
#    {'matched_elme_id': 949021931793,
#     'matched_elme_name': '合味道 五香牛肉风味方便面 77g/杯',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2063},
#    {'matched_elme_id': 950657484362,
#     'matched_elme_name': '麻辣王子 很麻很辣麻辣条 73g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1864}]},
#  20426248351: {'meituan_name': '余同乐 素食北京烤鸭其他豆制品 76g_袋',
#   'meituan_spec': '76g*1袋',
#   'top_matches': [{'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3548},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317544670: {'meituan_name': '双汇 台式烤香肠 38g_袋',
#   'meituan_spec': '38g*1袋',
#   'top_matches': [{'matched_elme_id': 949031079366,
#     'matched_elme_name': '双汇 台式烤香肠 38g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9401},
#    {'matched_elme_id': 950657120093,
#     'matched_elme_name': '汤达人 日式豚骨拉面 83g(面饼55g+配料28g)/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0},
#    {'matched_elme_id': 950103769331,
#     'matched_elme_name': '康师傅 BIG大食桶老坛酸菜牛肉面 159g/桶',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.0}]},
#  20317832437: {'meituan_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#   'meituan_spec': '18g*1袋',
#   'top_matches': [{'matched_elme_id': 949032555760,
#     'matched_elme_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9696},
#    {'matched_elme_id': 950657484362,
#     'matched_elme_name': '麻辣王子 很麻很辣麻辣条 73g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2584},
#    {'matched_elme_id': 950128361417,
#     'matched_elme_name': '优粮 小滑头儿时回忆怀旧小零食素食经典 18g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1609}]},
#  20318422176: {'meituan_name': '卫龙 香辣味大面筋辣条102g／袋 卫龙休闲小零食',
#   'meituan_spec': '102g*1袋',
#   'top_matches': [{'matched_elme_id': 949013951817,
#     'matched_elme_name': '卫龙亲嘴烧 经典香辣味调味面制品 20g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.4263},
#    {'matched_elme_id': 949032555760,
#     'matched_elme_name': '麻辣王子 地道辣条微麻微辣 18g／袋 网红平江辣条',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2227},
#    {'matched_elme_id': 949045691487,
#     'matched_elme_name': '【口味随机】旺仔 QQ糖休闲小零食 20g／袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2203}]},
#  20512614732: {'meituan_name': '迪味臻 山椒味泡椒凤爪 35g_袋',
#   'meituan_spec': '32g*1袋',
#   'top_matches': [{'matched_elme_id': 949479934319,
#     'matched_elme_name': '迪味臻五香卤蛋 30g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3051},
#    {'matched_elme_id': 950672352489,
#     'matched_elme_name': '王小卤 香辣味虎皮凤爪 105g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2684},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2217}]},
#  20428212802: {'meituan_name': '琥珀小米锅巴 麻辣味小米锅巴含油型膨化食品 22g_袋',
#   'meituan_spec': '22g*1袋',
#   'top_matches': [{'matched_elme_id': 949473714726,
#     'matched_elme_name': '上好佳 鲜虾片膨化食品 80克/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.3129},
#    {'matched_elme_id': 950676368263,
#     'matched_elme_name': '南街村 北京麻辣方便面 65g／袋 儿时的味道经典麻辣味',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2718},
#    {'matched_elme_id': 949472446011,
#     'matched_elme_name': '上好佳Oishi 无反式脂肪海苔味日式鱼果膨化食品 50g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1968}]},
#  20595280329: {'meituan_name': '康师傅 方便面 112g_桶【口味随机】',
#   'meituan_spec': '112g*1桶',
#   'top_matches': [{'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9365},
#    {'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2033},
#    {'matched_elme_id': 950094933365,
#     'matched_elme_name': '康师傅 低糖绿茶饮料 1l/瓶【红绿随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.1819}]},
#  20318701286: {'meituan_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g_袋',
#   'meituan_spec': '35g*1袋',
#   'top_matches': [{'matched_elme_id': 950662664340,
#     'matched_elme_name': '【口味随机】小浣熊 干脆面有肉任性油炸方便面 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.9571},
#    {'matched_elme_id': 950660220015,
#     'matched_elme_name': '中街 糯米糍香草口味雪糕 35g/袋',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.294},
#    {'matched_elme_id': 950103657459,
#     'matched_elme_name': '康师傅 方便面 112g/桶【口味随机】',
#     'matched_elme_spec': nan,
#     'similarity_score': 0.2439}]}}

# %%
# 结果存储为csv,第一列为待匹配列，后面为匹配列
pd.DataFrame(products).T.to_csv("./meituan_elme_match_result.csv", encoding="utf-8-sig")
